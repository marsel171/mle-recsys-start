# %% [markdown]
# # Initialization

# %%
import logging

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Загрузка данных

# %%
items = pd.read_parquet("items.par")
events = pd.read_parquet("events.par")

events_train = pd.read_parquet("events_train.par")
events_test = pd.read_parquet("events_test.par")

# %% [markdown]
# # Разбиение с учётом хронологии

# %% [markdown]
# Рекомендательные системы на практике работают с учётом хронологии. Поэтому поток событий для тренировки и валидации полезно делить на то, что уже случилось, и что ещё случится. Это позволяет проводить валидацию на тех же пользователях, на которых тренировались, но на их событиях в будущем.

# %% [markdown]
# # === Знакомство: "холодный" старт

# %%
users_train = events_train["user_id"].drop_duplicates().to_frame().reset_index(drop=True)
users_test = events_test["user_id"].drop_duplicates().to_frame().reset_index(drop=True)

common_users = users_train.merge(users_test,on="user_id",how="outer",indicator="indic")
common_users
# Out:
#         user_id      indic
# 0       1000000  left_only
# 1       1000001  left_only
# 2       1000002  left_only
# 3       1000003       both
# 4       1000004  left_only
# ...         ...        ...
# 430580  1430580       both
# 430581  1430581  left_only
# 430582  1430582  left_only
# 430583  1430583  left_only
# 430584  1430584       both
#
# [430585 rows x 2 columns]

# %%
cold_users = common_users[common_users["indic"] == "right_only"]["user_id"]

print(len(cold_users))
# Out:
# 2365

# %%
cold_users
# Out:
# 153       1000153
# 325       1000325
# 504       1000504
# 712       1000712
# 806       1000806
#            ...
# 429834    1429834
# 429875    1429875
# 430053    1430053
# 430311    1430311
# 430500    1430500
# Name: user_id, Length: 2365, dtype: int64

# %%
events_train
# Out:
#           user_id   item_id  started_at     read_at  is_read  rating  \
# 0         1000000      5350  2016-03-18  2016-04-03     True       4
# 1         1000000      6748  2016-04-16  2016-04-30     True       5
# 2         1000000  17675462  2016-07-06  2016-07-15     True       5
# 3         1000000  25494343  2016-06-10  2016-07-06     True       4
# 4         1000000  17851885  2016-08-01  2016-08-09     True       4
# ...           ...       ...         ...         ...      ...     ...
# 11751081  1430584   7896527  2016-05-18  2016-06-03     True       4
# 11751082  1430584  29056083  2016-08-01  2016-08-03     True       3
# 11751083  1430584   6614960  2015-11-02  2015-12-25     True       3
# 11751084  1430584   3153910  2014-06-11  2014-07-01     True       5
# 11751085  1430584      7445  2016-04-24  2016-05-18     True       4
#
#           is_reviewed started_at_month
# 0               False       2016-03-01
# 1               False       2016-04-01
# 2               False       2016-07-01
# 3               False       2016-06-01
# 4               False       2016-08-01
# ...               ...              ...
# 11751081         True       2016-05-01
# 11751082         True       2016-08-01
# 11751083        False       2015-11-01
# 11751084        False       2014-06-01
# 11751085         True       2016-04-01
#
# [11326124 rows x 8 columns]

# %%
# топ-100 наиболее популярных книг

top_pop_start_date = pd.to_datetime("2015-01-01").date()

item_popularity = events_train \
    .query("started_at >= @top_pop_start_date") \
    .groupby(["item_id"]).agg(users=("user_id", "nunique"), avg_rating=("rating", "mean")).reset_index()
item_popularity

# %%
item_popularity["popularity_weighted"] = item_popularity["users"] * item_popularity["avg_rating"]
item_popularity

# %%
# сортируем по убыванию взвешенной популярности
item_popularity = item_popularity.sort_values(by="popularity_weighted",ascending=False).reset_index(drop=True)
item_popularity

# %%
# выбираем первые 100 айтемов со средней оценкой avg_rating не меньше 4
top_k_pop_items = item_popularity[item_popularity["avg_rating"]>=4].head(100).reset_index(drop=True)
top_k_pop_items

# %%
# добавляем информацию о книгах
top_k_pop_items = top_k_pop_items.merge(
    items.set_index("item_id")[["author", "title", "genre_and_votes", "publication_year"]], on="item_id")

with pd.option_context('display.max_rows', 10):
    display(top_k_pop_items[["item_id", "author", "title", "publication_year", "users", "avg_rating", "popularity_weighted", "genre_and_votes"]])

# %%
# Для какой доли событий «холодных» пользователей в events_test рекомендации в top_k_pop_items совпали по книгам?
cold_users_events_with_recs = \
    events_test[events_test["user_id"].isin(cold_users)] \
    .merge(top_k_pop_items, on="item_id", how="left")
cold_users_events_with_recs

# %%
cold_user_items_no_avg_rating_idx = cold_users_events_with_recs["avg_rating"].isnull()
cold_user_items_no_avg_rating_idx

# %%
cold_user_recs = cold_users_events_with_recs[~cold_user_items_no_avg_rating_idx] \
    [["user_id", "item_id", "rating", "avg_rating"]]
cold_user_recs

# %%
# Верный ответ — 0,8023 (без округления). Книги в top_k_pop_items настолько популярны, что большая часть «холодных» пользователей их читала! 
1-1912/9672

# %%
# посчитаем метрики рекомендаций
# Посчитайте метрики rmse и mae для полученных рекомендаций.
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = mean_squared_error(cold_user_recs["rating"], cold_user_recs["avg_rating"], squared=False)
mae = mean_absolute_error(cold_user_recs["rating"], cold_user_recs["avg_rating"])
print(round(rmse, 2), round(mae, 2))

# Верный ответ — 0,62. В среднем оценка рекомендации отклоняется от истинной на такую величину.
#  Для пятибалльной шкалы отклонение невысокое, но и метрика посчитана по популярным книгам с высокими оценками.

# %%
# посчитаем покрытие холодных пользователей рекомендациями

cold_users_hit_ratio = cold_users_events_with_recs.groupby("user_id").agg(hits=("avg_rating", lambda x: (~x.isnull()).mean()))

print(f"Доля пользователей без релевантных рекомендаций: {(cold_users_hit_ratio == 0).mean().iat[0]:.2f}")
print(f"Среднее покрытие пользователей: {cold_users_hit_ratio[cold_users_hit_ratio != 0].mean().iat[0]:.2f}")

# «Холодных» пользователей без каких-либо релевантных рекомендаций — 57%,
#  то есть пересечение между оценёнными книгами и рекомендациями есть только у 43%, 
# по ним же и получено значение MAE-метрики. При этом среднее покрытие — 46%. 
# Это значит, что большая часть «холодных» пользователей не получила никаких релевантных рекомендаций, 
# а оставшаяся часть имеет пересечения только по 46% книг.

# %% [markdown]
# # === Знакомство: первые персональные рекомендации

# %%
events.head()
# Out:
#    user_id   item_id  started_at     read_at  is_read  rating  is_reviewed  \
# 0  1000000      5350  2016-03-18  2016-04-03     True       4        False
# 1  1000000      6748  2016-04-16  2016-04-30     True       5        False
# 2  1000000  17675462  2016-07-06  2016-07-15     True       5        False
# 3  1000000  25494343  2016-06-10  2016-07-06     True       4        False
# 4  1000000  17851885  2016-08-01  2016-08-09     True       4        False
#
#   started_at_month
# 0       2016-03-01
# 1       2016-04-01
# 2       2016-07-01
# 3       2016-06-01
# 4       2016-08-01

# %%
# Степень разреженности матрицы
print(len(events["rating"]))
print(len(items))
print(len(events["user_id"].drop_duplicates().to_frame().reset_index(drop=True)))
# Out:
# 11751086
# 43312
# 430585

# %%
(43312*430585-11751086)/(43312*430585)
# Out:
# 0.9993698979831817

# %% [markdown]
# # === Базовые подходы: коллаборативная фильтрация

# %%
# Реализация SVD-алгоритма

from surprise import Dataset, Reader
from surprise import SVD

# %%
# используем Reader из библиотеки surprise для преобразования событий (events)
# в формат, необходимый surprise
reader = Reader(rating_scale=(1, 5))
surprise_train_set = Dataset.load_from_df(events_train[['user_id', 'item_id', 'rating']], reader)
surprise_train_set

# %%
surprise_train_set = surprise_train_set.build_full_trainset()

# инициализируем модель
svd_model = SVD(n_factors=100, random_state=0)

# обучаем модель
svd_model.fit(surprise_train_set)

# %%
surprise_test_set = list(events_test[['user_id', 'item_id', 'rating']].itertuples(index=False))

# получаем рекомендации для тестовой выборки
svd_predictions = svd_model.test(surprise_test_set)

# %%
svd_predictions
# Out:
# [Prediction(uid=1000003, iid=25893709, r_ui=4, est=3.047716878985341, details={'was_impossible': False}),
#  Prediction(uid=1000005, iid=34076952, r_ui=5, est=4.041735872183185, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=18812405, r_ui=3, est=3.999472296100204, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=7445, r_ui=4, est=4.41194063156509, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=29868610, r_ui=4, est=4.29199912216072, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=18774964, r_ui=4, est=4.642092319255585, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=24817626, r_ui=3, est=3.2471586563355213, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=24453082, r_ui=3, est=3.7193525750864227, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=28257707, r_ui=4, est=3.9574089125393153, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=168642, r_ui=5, est=3.9954585182442885, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=31226744, r_ui=4, est=3.7443255131035613, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=40440, r_ui=4, est=4.099872971646494, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=8354134, r_ui=4, est=4.521736089965755, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=5, r_ui=5, est=4.798885895633344, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=92367, r_ui=3, est=3.240961287514684, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=13154150, r_ui=4, est=3.9017180509752665, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=37415, r_ui=4, est=4.277851237229425, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=7093952, r_ui=3, est=4.220722965637715, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=13496, r_ui=2, est=4.424537798873998, details={'was_impossible': False}),
#  Prediction(uid=1000020, iid=38447, r_ui=3, est=3.475433400009313, details={'was_impossible': False}),
#  Prediction(uid=1000020, iid=5203, r_ui=4, est=3.142408131522348, details={'was_impossible': False}),
#  Prediction(uid=1000023, iid=5094, r_ui=3, est=4.259216972363774, details={'was_impossible': False}),
#  Prediction(uid=1000023, iid=7260188, r_ui=5, est=3.9622583158918743, details={'was_impossible': False}),
#  Prediction(uid=1000025, iid=29056083, r_ui=3, est=4.197758054546885, details={'was_impossible': False}),
#  Prediction(uid=1000032, iid=17333223, r_ui=5, est=3.935878169426151, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=28305, r_ui=1, est=3.7615454454318673, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=14942, r_ui=5, est=3.2135541949577577, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=2247142, r_ui=3, est=3.8827684006454595, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=23164983, r_ui=1, est=3.7475834844006997, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=897363, r_ui=4, est=3.9991121666935605, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=13812, r_ui=2, est=3.5986926409650812, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=6288, r_ui=2, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=7670, r_ui=4, est=3.9737282773236906, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=5060378, r_ui=4, est=3.940490350925824, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=6327, r_ui=1, est=3.648777217421636, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=5470, r_ui=5, est=3.7240901457762683, details={'was_impossible': False}),
#  Prediction(uid=1000037, iid=12394068, r_ui=5, est=4.033977275454496, details={'was_impossible': False}),
#  Prediction(uid=1000038, iid=14864, r_ui=5, est=3.7323363267356373, details={'was_impossible': False}),
#  Prediction(uid=1000040, iid=20564, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000043, iid=17235026, r_ui=5, est=3.9158899246165255, details={'was_impossible': False}),
#  Prediction(uid=1000043, iid=46756, r_ui=4, est=3.919283406465152, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=17607850, r_ui=5, est=3.7399233479432206, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=29991719, r_ui=5, est=4.183682919627077, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=17607848, r_ui=5, est=3.828831058558106, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=20448515, r_ui=5, est=3.5170412641150524, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=13596809, r_ui=5, est=3.939284970718476, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=91477, r_ui=5, est=4.237886467232384, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=47212, r_ui=5, est=4.369011931358201, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=29863848, r_ui=4, est=4.346902347489525, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=13596809, r_ui=5, est=4.770420246222418, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=15731779, r_ui=5, est=4.770274775848356, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=24485589, r_ui=5, est=4.707018210263112, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=27827203, r_ui=5, est=4.384262165340793, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=7896527, r_ui=4, est=4.758041324107568, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=7664334, r_ui=5, est=4.8379116997762, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=23308084, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=18798983, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=18045891, r_ui=4, est=4.942929801689335, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=20448515, r_ui=5, est=4.507206360961017, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=20613470, r_ui=4, est=4.291481073479003, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=9969571, r_ui=4, est=4.189903178725916, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=10025305, r_ui=4, est=3.8167066800451095, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=18335634, r_ui=5, est=4.0765339929232525, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=23437156, r_ui=5, est=4.16822268579679, details={'was_impossible': False}),
#  Prediction(uid=1000054, iid=8683812, r_ui=2, est=2.6540737853752634, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=9409458, r_ui=3, est=3.135364619073461, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=6654313, r_ui=3, est=3.2444347871082764, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=29056083, r_ui=3, est=3.083969117265483, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=27695, r_ui=4, est=3.238112040103977, details={'was_impossible': False}),
#  Prediction(uid=1000056, iid=25111004, r_ui=5, est=4.614526947032485, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=25489625, r_ui=5, est=4.975753903913588, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=28458598, r_ui=5, est=4.329378581780937, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=432, r_ui=4, est=3.797995223523639, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=56616, r_ui=4, est=4.537553719212753, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=5439, r_ui=5, est=4.753680906965252, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=3447, r_ui=3, est=4.2105450939468225, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=34111673, r_ui=4, est=4.127942867639025, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=2906039, r_ui=3, est=3.5605666785582493, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=34189556, r_ui=5, est=4.2010393594422615, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=27406704, r_ui=2, est=4.17202180085649, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=31111142, r_ui=4, est=3.909542603795157, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=33280872, r_ui=4, est=4.339583725961977, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=18774964, r_ui=5, est=4.632303078266724, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=33230889, r_ui=5, est=4.226734493400564, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=32148091, r_ui=5, est=3.963524463556148, details={'was_impossible': False}),
#  Prediction(uid=1000069, iid=22886868, r_ui=5, est=3.7631390579183983, details={'was_impossible': False}),
#  Prediction(uid=1000069, iid=15790883, r_ui=4, est=3.881049639534837, details={'was_impossible': False}),
#  Prediction(uid=1000070, iid=29638254, r_ui=4, est=4.494753862337572, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=2165, r_ui=5, est=3.8774474482870254, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=3181564, r_ui=3, est=4.185850096769657, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=30008702, r_ui=5, est=4.135489753976569, details={'was_impossible': False}),
#  Prediction(uid=1000077, iid=17333174, r_ui=5, est=4.686038342151156, details={'was_impossible': False}),
#  Prediction(uid=1000084, iid=23168277, r_ui=4, est=3.56491183397911, details={'was_impossible': False}),
#  Prediction(uid=1000084, iid=2372, r_ui=3, est=3.718573771131162, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=4214, r_ui=4, est=3.8986404030693365, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=268275, r_ui=3, est=3.789360447455382, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=20454672, r_ui=4, est=4.260940968633408, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29864343, r_ui=3, est=4.192244077320669, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=25893709, r_ui=3, est=3.5675617348620183, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=26154406, r_ui=3, est=3.79317926318818, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=77477, r_ui=3, est=3.647998910674504, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=760924, r_ui=4, est=4.076520027323552, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=8755776, r_ui=3, est=4.178671948392361, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29780253, r_ui=5, est=4.745508271920529, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=15791085, r_ui=3, est=4.200919058229654, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29496076, r_ui=5, est=4.298723524718244, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=25150798, r_ui=3, est=4.302182504944806, details={'was_impossible': False}),
#  Prediction(uid=1000086, iid=28815474, r_ui=4, est=4.322189219253672, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=12969140, r_ui=2, est=4.256245602566286, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=9516, r_ui=5, est=4.164700302301874, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=1, r_ui=4, est=4.630501616575491, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=32075671, r_ui=4, est=4.936798462661809, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=22918050, r_ui=3, est=3.7431538241051285, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=30333938, r_ui=4, est=4.206420798316866, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=24445517, r_ui=4, est=4.647108808437348, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=18140047, r_ui=4, est=4.213519384363876, details={'was_impossible': False}),
#  Prediction(uid=1000114, iid=87745, r_ui=3, est=3.636918610831208, details={'was_impossible': False}),
#  Prediction(uid=1000117, iid=16143347, r_ui=3, est=3.979000873193013, details={'was_impossible': False}),
#  Prediction(uid=1000118, iid=1582996, r_ui=4, est=4.290254618562868, details={'was_impossible': False}),
#  Prediction(uid=1000122, iid=102868, r_ui=4, est=3.9750566044895144, details={'was_impossible': False}),
#  Prediction(uid=1000122, iid=89717, r_ui=4, est=3.79213370725763, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=18774964, r_ui=5, est=4.190146487011144, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=25558608, r_ui=3, est=4.212243683411149, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=11447921, r_ui=3, est=3.3684541270920727, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=5246, r_ui=4, est=3.3635606418210284, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=27774758, r_ui=4, est=4.181797011569982, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=25489625, r_ui=4, est=4.0129520166771, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=6136509, r_ui=3, est=4.0801186716975355, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=11275, r_ui=3, est=3.7410254536359595, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=5948907, r_ui=4, est=3.955954049391771, details={'was_impossible': False}),
#  Prediction(uid=1000128, iid=18635622, r_ui=3, est=4.231204703933897, details={'was_impossible': False}),
#  Prediction(uid=1000128, iid=11970747, r_ui=4, est=3.9507420841348617, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=13497, r_ui=4, est=4.235300547599359, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=2, r_ui=5, est=4.542566031308635, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=102733, r_ui=5, est=3.828898886800451, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=10664113, r_ui=3, est=4.4090948100023235, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=5096, r_ui=4, est=4.193089521056189, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=47212, r_ui=5, est=3.9875515647014654, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=5, r_ui=5, est=4.681463600040265, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=15881, r_ui=5, est=4.527577213611475, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=184655, r_ui=4, est=4.280844444442911, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=3, r_ui=5, est=4.555794311190833, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=184661, r_ui=4, est=4.050445745615401, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=17571466, r_ui=4, est=3.612779234203773, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=29875363, r_ui=5, est=3.890105690123455, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=34466922, r_ui=2, est=4.009775180338429, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=6, r_ui=5, est=4.633822935708506, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=29437949, r_ui=4, est=3.3479106815341693, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=3087, r_ui=2, est=3.176852040568889, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=32102, r_ui=3, est=3.295813725712675, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=19288043, r_ui=5, est=3.141020560975686, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=10874177, r_ui=3, est=3.136022270582068, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=13497818, r_ui=4, est=2.877508601075216, details={'was_impossible': False}),
#  Prediction(uid=1000141, iid=32148570, r_ui=5, est=4.704014315485587, details={'was_impossible': False}),
#  Prediction(uid=1000143, iid=12898, r_ui=3, est=3.6294241226663666, details={'was_impossible': False}),
#  Prediction(uid=1000144, iid=38447, r_ui=5, est=4.3544000292663645, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=34273236, r_ui=4, est=4.299963596474619, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=32585, r_ui=3, est=3.646324044001666, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29780253, r_ui=5, est=4.537250569307518, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29430049, r_ui=3, est=3.5583270465472614, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29868610, r_ui=3, est=3.5393147117234167, details={'was_impossible': False}),
#  Prediction(uid=1000146, iid=1255781, r_ui=3, est=3.861793779981579, details={'was_impossible': False}),
#  Prediction(uid=1000146, iid=10929, r_ui=4, est=3.4559019105308555, details={'was_impossible': False}),
#  Prediction(uid=1000148, iid=102868, r_ui=5, est=4.2588469720155375, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=34928122, r_ui=5, est=4.382254739166465, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=16101135, r_ui=4, est=4.038139115672008, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=14996, r_ui=5, est=4.25992793775565, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=29923707, r_ui=4, est=4.095847350159571, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=31450852, r_ui=5, est=3.9825229549665533, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=30025336, r_ui=4, est=4.087152259303616, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=18806259, r_ui=3, est=3.6176443590887866, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=13262783, r_ui=5, est=4.005379534979796, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=26114463, r_ui=5, est=4.226138848342429, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=29236299, r_ui=5, est=4.582509159362102, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=402093, r_ui=4, est=3.815069460035719, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=28695, r_ui=4, est=3.6877044530963357, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=9496240, r_ui=2, est=3.34241880471083, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=77507, r_ui=3, est=3.3116845896480323, details={'was_impossible': False}),
#  Prediction(uid=1000163, iid=9969571, r_ui=3, est=4.3356960547123435, details={'was_impossible': False}),
#  Prediction(uid=1000165, iid=33897359, r_ui=3, est=3.9351347089058244, details={'was_impossible': False}),
#  Prediction(uid=1000175, iid=31450908, r_ui=4, est=4.451677790432748, details={'was_impossible': False}),
#  Prediction(uid=1000175, iid=26114463, r_ui=5, est=4.468895665265332, details={'was_impossible': False}),
#  Prediction(uid=1000178, iid=10964, r_ui=5, est=3.986934067876738, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=18812405, r_ui=4, est=4.476202767966577, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=25074850, r_ui=4, est=4.3478010611620155, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=15818107, r_ui=4, est=4.611365265095723, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=22318578, r_ui=5, est=4.0101620350099525, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=38447, r_ui=4, est=4.660036354614559, details={'was_impossible': False}),
#  Prediction(uid=1000183, iid=30821598, r_ui=3, est=4.266384553767552, details={'was_impossible': False}),
#  Prediction(uid=1000187, iid=26114463, r_ui=5, est=4.498371128115393, details={'was_impossible': False}),
#  Prediction(uid=1000187, iid=10614, r_ui=4, est=4.642709256688096, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=29397486, r_ui=5, est=4.1509559050949285, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=17738800, r_ui=4, est=4.142211745534302, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=5960325, r_ui=5, est=4.073457593570217, details={'was_impossible': False}),
#  Prediction(uid=1000195, iid=15798797, r_ui=3, est=4.567902737652573, details={'was_impossible': False}),
#  Prediction(uid=1000195, iid=4671, r_ui=4, est=4.09558947698821, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=34121119, r_ui=3, est=3.3585094326553087, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=29496453, r_ui=5, est=4.18034293257817, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=3431, r_ui=4, est=3.596085240912967, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=4894, r_ui=4, est=3.3574056207515857, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=10929, r_ui=4, est=3.6846989660826353, details={'was_impossible': False}),
#  Prediction(uid=1000199, iid=280412, r_ui=5, est=4.52302919648891, details={'was_impossible': False}),
#  Prediction(uid=1000199, iid=657034, r_ui=4, est=4.185211462800354, details={'was_impossible': False}),
#  Prediction(uid=1000201, iid=38447, r_ui=4, est=4.364904369736082, details={'was_impossible': False}),
#  Prediction(uid=1000203, iid=166997, r_ui=5, est=4.049852072693869, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=21611, r_ui=3, est=4.241881745884212, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=7959038, r_ui=5, est=3.4785723711482874, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=2767793, r_ui=5, est=4.430344293830664, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=24861, r_ui=5, est=3.9918606133424066, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=9717, r_ui=5, est=4.154160739400881, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=537094, r_ui=3, est=3.942070401718038, details={'was_impossible': False}),
#  Prediction(uid=1000207, iid=85812, r_ui=2, est=2.853066599963058, details={'was_impossible': False}),
#  Prediction(uid=1000207, iid=27037, r_ui=1, est=2.731272620249614, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=345627, r_ui=5, est=4.431614525032502, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=17724774, r_ui=4, est=3.5133863981762623, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=31931941, r_ui=4, est=4.563120393671272, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=23719270, r_ui=3, est=4.054134242950838, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=136251, r_ui=5, est=4.901903462542359, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=1, r_ui=5, est=4.828893867841473, details={'was_impossible': False}),
#  Prediction(uid=1000214, iid=5107, r_ui=5, est=3.8493737669787356, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=22918050, r_ui=4, est=3.967893895846525, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=16248068, r_ui=4, est=4.342277272044477, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=18635016, r_ui=4, est=4.358300667103983, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=95382, r_ui=3, est=4.154690810941317, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=23127048, r_ui=4, est=3.9577590950698127, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=23093367, r_ui=5, est=4.609903747874312, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=15732712, r_ui=3, est=3.8929764512961906, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=10210, r_ui=5, est=4.180223276783597, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=6, r_ui=4, est=4.702043368804807, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=29396738, r_ui=5, est=4.066350159295542, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=17167166, r_ui=3, est=4.308684799006203, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=32075671, r_ui=5, est=4.545133332098821, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=32905343, r_ui=3, est=3.6480930360709043, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=33984056, r_ui=3, est=3.63832409908417, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=34114362, r_ui=4, est=3.666541799238793, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=31123261, r_ui=4, est=3.575206180113387, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=33843362, r_ui=3, est=3.2465540392346472, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=7093952, r_ui=4, est=3.980319013784417, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=23282249, r_ui=4, est=3.565348812966482, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=29749085, r_ui=4, est=4.124802685455061, details={'was_impossible': False}),
#  Prediction(uid=1000231, iid=28390369, r_ui=3, est=3.0494409266914997, details={'was_impossible': False}),
#  Prediction(uid=1000231, iid=8909152, r_ui=3, est=3.5229228855783106, details={'was_impossible': False}),
#  Prediction(uid=1000234, iid=9440324, r_ui=4, est=3.7359363826849212, details={'was_impossible': False}),
#  Prediction(uid=1000234, iid=15745753, r_ui=4, est=4.363074590109908, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=29906980, r_ui=3, est=3.557451504938421, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=32388712, r_ui=3, est=3.0209135988805915, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30687041, r_ui=3, est=3.8119710513917604, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30555488, r_ui=4, est=3.5743941817154825, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30244626, r_ui=3, est=3.580651760451516, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30259893, r_ui=3, est=3.9344106818992093, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=28390369, r_ui=2, est=4.077781018313429, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=8492768, r_ui=4, est=4.18000306969662, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=33984056, r_ui=4, est=3.6557836679137083, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=12262741, r_ui=3, est=3.979713191649789, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=25251757, r_ui=3, est=3.606071619586207, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=18007564, r_ui=5, est=4.572120702469433, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=25663717, r_ui=4, est=3.8799579401933797, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=12088102, r_ui=5, est=3.6685913027632546, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=30724132, r_ui=3, est=3.704958773687543, details={'was_impossible': False}),
#  Prediction(uid=1000254, iid=23731881, r_ui=5, est=4.70850737370775, details={'was_impossible': False}),
#  Prediction(uid=1000254, iid=853510, r_ui=4, est=4.148643409041946, details={'was_impossible': False}),
#  Prediction(uid=1000256, iid=38315, r_ui=4, est=4.204080476398663, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=31309, r_ui=3, est=3.3689144000592446, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=900682, r_ui=5, est=3.106070541900543, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=386286, r_ui=4, est=3.0038052452499957, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=267102, r_ui=4, est=3.4028662475341314, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=34, r_ui=5, est=3.2867696413791174, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=18512, r_ui=5, est=3.57805966551987, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=15241, r_ui=5, est=3.6023981740732167, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=30688435, r_ui=5, est=3.6273869094159052, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=31451186, r_ui=4, est=3.9190960211505144, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=6345760, r_ui=4, est=4.01291606197839, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=32388712, r_ui=4, est=3.887164372415341, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=32439, r_ui=2, est=2.978141807839323, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=17137623, r_ui=5, est=3.500700675026929, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=32445, r_ui=1, est=3.1532984793745475, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=15777797, r_ui=5, est=2.8440555068474347, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=16431, r_ui=2, est=3.0309302722150058, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=228221, r_ui=2, est=2.4139883532590027, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=28321033, r_ui=2, est=3.218984486156434, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=51606, r_ui=5, est=3.9349098505849995, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=12395, r_ui=1, est=3.527857917040022, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=50466, r_ui=3, est=3.559079053399439, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=21027, r_ui=4, est=3.898255387756046, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=141526, r_ui=4, est=3.1523424986569326, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=4796, r_ui=5, est=3.715953439869232, details={'was_impossible': False}),
#  Prediction(uid=1000293, iid=960, r_ui=4, est=3.7338830644518244, details={'was_impossible': False}),
#  Prediction(uid=1000293, iid=20170404, r_ui=4, est=3.8831937367759513, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=140974, r_ui=5, est=4.036980046001819, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=15704307, r_ui=5, est=4.934236350166539, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=13891, r_ui=5, est=4.270770304991672, details={'was_impossible': False}),
#  Prediction(uid=1000301, iid=178788, r_ui=5, est=4.1117315566200165, details={'was_impossible': False}),
#  Prediction(uid=1000305, iid=23301545, r_ui=5, est=4.145759430907786, details={'was_impossible': False}),
#  Prediction(uid=1000306, iid=27274207, r_ui=4, est=4.028155075751707, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=17607850, r_ui=5, est=4.081971148206956, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=15283043, r_ui=4, est=4.088762509281776, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=17607848, r_ui=5, est=4.340977617772427, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=20448515, r_ui=4, est=4.776325396667811, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=13596809, r_ui=5, est=4.993246594960846, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=11918, r_ui=4, est=4.104687518415714, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=15731779, r_ui=5, est=4.888825163235326, details={'was_impossible': False}),
#  Prediction(uid=1000321, iid=23341862, r_ui=4, est=4.111208519399458, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=23395680, r_ui=5, est=3.9610723022851153, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=13619, r_ui=4, est=4.2315238410461955, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=13618, r_ui=4, est=4.290119174061317, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=3657138, r_ui=2, est=3.153323291201578, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=16160797, r_ui=4, est=3.9218641295191574, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=11777020, r_ui=4, est=3.6723103398898083, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=9572203, r_ui=5, est=4.03041856757153, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=19101283, r_ui=4, est=4.163800848684492, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=1991039, r_ui=4, est=3.408231442709636, details={'was_impossible': False}),
#  Prediction(uid=1000327, iid=7613, r_ui=5, est=4.209972994539752, details={'was_impossible': False}),
#  Prediction(uid=1000327, iid=1885, r_ui=5, est=4.259798384286833, details={'was_impossible': False}),
#  Prediction(uid=1000333, iid=25740412, r_ui=4, est=3.3637455085290986, details={'was_impossible': False}),
#  Prediction(uid=1000335, iid=8752885, r_ui=4, est=3.2547706633345337, details={'was_impossible': False}),
#  Prediction(uid=1000335, iid=30688013, r_ui=5, est=4.4124621065736465, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=28187230, r_ui=4, est=3.9221724954489408, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=149267, r_ui=5, est=4.232590163853321, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=43615, r_ui=3, est=4.409698566291276, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=14942, r_ui=3, est=4.342816148232218, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=32692, r_ui=4, est=4.21652795607211, details={'was_impossible': False}),
#  Prediction(uid=1000349, iid=83143, r_ui=5, est=4.465121309875588, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=28006120, r_ui=3, est=3.155530921076852, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=16160797, r_ui=4, est=3.325658378312543, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=38447, r_ui=4, est=3.510056342666748, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=18214414, r_ui=3, est=3.504703382342799, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=18081809, r_ui=4, est=2.8550713259596647, details={'was_impossible': False}),
#  Prediction(uid=1000360, iid=131359, r_ui=4, est=4.141272529290819, details={'was_impossible': False}),
#  Prediction(uid=1000361, iid=1, r_ui=4, est=4.799860072452743, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=10507293, r_ui=4, est=4.44427879505879, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=18172471, r_ui=5, est=4.604615465283956, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=16248068, r_ui=5, est=4.216794504018847, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=9004758, r_ui=4, est=3.8424903254711618, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=16178, r_ui=5, est=4.2632729736630415, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=3678651, r_ui=4, est=3.8158498085976165, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=6318426, r_ui=5, est=4.311364866832107, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=649514, r_ui=5, est=4.357126175678782, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=830502, r_ui=5, est=4.127429259062118, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=136814, r_ui=5, est=4.587019697801663, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=202372, r_ui=5, est=4.194741701097222, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=12862611, r_ui=5, est=4.312503780930465, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=32075671, r_ui=5, est=4.913787872428602, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=7445, r_ui=5, est=4.5351688583778405, details={'was_impossible': False}),
#  Prediction(uid=1000381, iid=31360, r_ui=5, est=3.93571184164309, details={'was_impossible': False}),
#  Prediction(uid=1000381, iid=3030779, r_ui=5, est=4.171375178744901, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=7670, r_ui=4, est=3.0694413129606355, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=813214, r_ui=3, est=3.245771658968147, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=67035, r_ui=3, est=3.5584439693816363, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=46756, r_ui=4, est=3.9413482722358197, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=1662160, r_ui=4, est=3.8950860491749655, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=22151696, r_ui=1, est=3.7746195630204755, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=18619684, r_ui=4, est=3.711412727079827, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=6900, r_ui=3, est=3.7897998655297434, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=18003300, r_ui=1, est=3.7191032653195792, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=5297, r_ui=4, est=3.786113647340668, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=6496815, r_ui=4, est=3.6990990770990377, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=983546, r_ui=4, est=3.6550419592841474, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=9625608, r_ui=3, est=3.7376931552186052, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=3398625, r_ui=3, est=3.320716456895441, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=43615, r_ui=3, est=3.3402743511806103, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=365672, r_ui=4, est=3.340931339461448, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=16142053, r_ui=3, est=3.868717610358535, details={'was_impossible': False}),
#  Prediction(uid=1000388, iid=27126, r_ui=4, est=3.6150418895383223, details={'was_impossible': False}),
#  Prediction(uid=1000390, iid=23692271, r_ui=5, est=4.6980202647067815, details={'was_impossible': False}),
#  Prediction(uid=1000390, iid=32560066, r_ui=5, est=4.4755427219051205, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=23203106, r_ui=1, est=2.7256508971815148, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=2956, r_ui=2, est=3.3714509885043764, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=17791477, r_ui=3, est=3.212360228499253, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=92303, r_ui=4, est=3.854652925447514, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=34484, r_ui=4, est=3.742399871393936, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=890, r_ui=2, est=3.3231297981137566, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=17199504, r_ui=2, est=2.4976204333785015, details={'was_impossible': False}),
#  Prediction(uid=1000399, iid=687278, r_ui=5, est=4.083841082534237, details={'was_impossible': False}),
#  Prediction(uid=1000399, iid=34114362, r_ui=4, est=3.6839409744849334, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=33280872, r_ui=4, est=3.896727450434322, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=30364190, r_ui=5, est=3.4249144088370143, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=27362503, r_ui=4, est=4.319682336658766, details={'was_impossible': False}),
#  Prediction(uid=1000404, iid=8490112, r_ui=4, est=3.831408242891832, details={'was_impossible': False}),
#  Prediction(uid=1000404, iid=2696, r_ui=4, est=3.4806813148022897, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=7076706, r_ui=4, est=3.423784507179263, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=17802747, r_ui=3, est=3.609605242860347, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=8667848, r_ui=5, est=3.979147840685863, details={'was_impossible': False}),
#  Prediction(uid=1000417, iid=14185, r_ui=5, est=3.9101771740443234, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=31450852, r_ui=3, est=3.955353498126434, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=12666103, r_ui=3, est=3.896103400653282, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=28962906, r_ui=5, est=3.521767630254211, details={'was_impossible': False}),
#  Prediction(uid=1000447, iid=43615, r_ui=5, est=3.4567849300813887, details={'was_impossible': False}),
#  Prediction(uid=1000447, iid=23277298, r_ui=4, est=3.6831108529201324, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=34273236, r_ui=5, est=4.673717538743915, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=18693763, r_ui=3, est=4.111004418474895, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=28187230, r_ui=3, est=3.5189995674168197, details={'was_impossible': False}),
#  Prediction(uid=1000456, iid=32326398, r_ui=4, est=3.6775194411022394, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=18798983, r_ui=2, est=3.303154087941839, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=25883848, r_ui=5, est=4.199946050347818, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=17927395, r_ui=5, est=4.039147058405052, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=28587957, r_ui=5, est=3.4469626252349403, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=1420, r_ui=3, est=2.831078405889389, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=23308084, r_ui=2, est=3.1426820465760614, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=27161156, r_ui=3, est=3.6743329818694175, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=26893819, r_ui=5, est=3.6417950864770683, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=25988934, r_ui=4, est=3.6554629966922363, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=27213168, r_ui=5, est=3.8263317574040685, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=16096824, r_ui=4, est=3.4339423701818004, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=500657, r_ui=3, est=2.991993228198649, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=27066722, r_ui=3, est=3.0119523179819887, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=374494, r_ui=3, est=3.1682361380153847, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=30259041, r_ui=4, est=3.1150941068690803, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=31125554, r_ui=2, est=3.319767035549916, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=12998057, r_ui=4, est=3.407211871943744, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=853510, r_ui=3, est=3.4192978901956095, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=61904, r_ui=3, est=3.171860684923918, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=24856069, r_ui=3, est=3.210117082811263, details={'was_impossible': False}),
#  Prediction(uid=1000466, iid=34466922, r_ui=4, est=3.9670073541683237, details={'was_impossible': False}),
#  Prediction(uid=1000466, iid=830502, r_ui=4, est=4.223488851530614, details={'was_impossible': False}),
#  Prediction(uid=1000476, iid=18869970, r_ui=3, est=3.4465163255143536, details={'was_impossible': False}),
#  Prediction(uid=1000476, iid=39999, r_ui=5, est=3.257240776396518, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=14384, r_ui=5, est=3.883452099559402, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=84133, r_ui=3, est=3.9747209181717142, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=23272028, r_ui=4, est=3.6112559025690816, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=29396738, r_ui=5, est=4.069533505409415, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=17316770, r_ui=4, est=3.6611029821206684, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=68783, r_ui=4, est=3.365765525150023, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=983567, r_ui=3, est=3.3756486784356206, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=27507850, r_ui=4, est=3.979412394382819, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=23174274, r_ui=4, est=3.7450520023381384, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=28187230, r_ui=3, est=3.4575230928069534, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=8694522, r_ui=3, est=3.3564814439394195, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=13597728, r_ui=4, est=2.96424305081637, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=33151805, r_ui=3, est=3.4976578742791364, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=6310782, r_ui=4, est=3.4017883222908853, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=4961048, r_ui=3, est=3.7289187492780727, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=52635, r_ui=3, est=3.5633056947961257, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=96908, r_ui=4, est=3.8506287644950086, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=6584188, r_ui=3, est=3.556822609723382, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=17838528, r_ui=3, est=4.058790578713785, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=8680278, r_ui=3, est=3.4377188465006467, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=15749186, r_ui=4, est=4.071219565791655, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=20698530, r_ui=4, est=4.174499274445512, details={'was_impossible': False}),
#  Prediction(uid=1000503, iid=13206900, r_ui=5, est=4.939033382296082, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=5907, r_ui=4, est=4.265372810308688, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=48855, r_ui=5, est=4.248100641367111, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=1885, r_ui=5, est=4.284421209462968, details={'was_impossible': False}),
#  Prediction(uid=1000505, iid=2164457, r_ui=3, est=3.4764328797029176, details={'was_impossible': False}),
#  Prediction(uid=1000505, iid=627055, r_ui=4, est=4.7117571342009015, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=22567177, r_ui=5, est=4.212015043537549, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=34128219, r_ui=5, est=3.709394169647192, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=386286, r_ui=4, est=3.5499980661364754, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=22567184, r_ui=5, est=4.498972704848313, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=12725, r_ui=3, est=3.432894553824072, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=6261522, r_ui=4, est=4.662590401088231, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=35439987, r_ui=4, est=4.134882846493969, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=24763621, r_ui=4, est=4.02873115076832, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=26135139, r_ui=3, est=3.601201725997119, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=23766634, r_ui=5, est=4.68541751279002, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=33280872, r_ui=5, est=4.024204424214337, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=18660447, r_ui=4, est=4.4309236130043566, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=22522202, r_ui=5, est=4.001106159764498, details={'was_impossible': False}),
# ...
#  Prediction(uid=1000955, iid=31304, r_ui=5, est=4.113300610991129, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=30312891, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=13254289, r_ui=4, est=4.5602523260310734, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=19208103, r_ui=5, est=4.393495345710857, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=16075962, r_ui=3, est=4.536452883503265, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=31450852, r_ui=5, est=4.423590007827383, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=13206760, r_ui=5, est=4.907517006218073, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=36381037, r_ui=5, est=4.726340998311948, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=1611656, r_ui=4, est=3.988748463729894, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=29923707, r_ui=5, est=4.134879982130522, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=28374007, r_ui=5, est=3.902904962876758, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=2003625, r_ui=4, est=4.17001265269992, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=13538873, r_ui=5, est=3.606325411734465, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=367689, r_ui=4, est=4.115065218156714, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=84151, r_ui=2, est=4.201889975689737, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=28477789, r_ui=4, est=4.239376348318543, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=23995491, r_ui=5, est=4.230535837455799, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=27876293, r_ui=4, est=3.502907219629114, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=24583, r_ui=4, est=3.3059032001238413, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=18774964, r_ui=4, est=4.140236435960122, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=4374400, r_ui=4, est=3.30226003623271, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=168642, r_ui=4, est=3.423147575265657, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=25807, r_ui=3, est=3.457790760471558, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=6582637, r_ui=3, est=4.075644748656864, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=3819326, r_ui=3, est=3.965693779190747, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=18342317, r_ui=5, est=4.053686484119327, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=25944798, r_ui=4, est=4.475845267275488, details={'was_impossible': False}),
#  Prediction(uid=1000967, iid=37415, r_ui=5, est=4.036081422338285, details={'was_impossible': False}),
#  Prediction(uid=1000967, iid=77203, r_ui=3, est=4.2507729336471405, details={'was_impossible': False}),
#  Prediction(uid=1000973, iid=7735333, r_ui=3, est=3.315823536795626, details={'was_impossible': False}),
#  Prediction(uid=1000973, iid=23492533, r_ui=3, est=3.903318218885002, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=22749788, r_ui=4, est=3.9643060716652694, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=8855321, r_ui=4, est=4.323215626665645, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=6487308, r_ui=3, est=2.9918356805227018, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=7740152, r_ui=3, est=3.0447670262340885, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=32758901, r_ui=5, est=4.450794922514332, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=16690, r_ui=5, est=4.125384199408698, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=23714109, r_ui=4, est=3.970480680169018, details={'was_impossible': False}),
#  Prediction(uid=1000978, iid=1618, r_ui=4, est=3.5139013729213375, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=33149088, r_ui=3, est=4.023242605131724, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=32487617, r_ui=4, est=4.564338990785945, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=29639736, r_ui=4, est=3.8422870017307384, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=11870085, r_ui=5, est=4.50801924164069, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=8909152, r_ui=5, est=4.4310620051961935, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=34684622, r_ui=5, est=4.234433008271871, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=24583, r_ui=3, est=4.2001150683723045, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=11447921, r_ui=4, est=4.430685578884946, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=23164927, r_ui=4, est=4.251635778556333, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=2767052, r_ui=5, est=4.72536931182818, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=656876, r_ui=3, est=3.837333056909703, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=6148028, r_ui=5, est=4.632195805134698, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=816870, r_ui=3, est=4.1529413871419525, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=257845, r_ui=5, est=4.4175598060914485, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=50144, r_ui=5, est=4.255555269055436, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=29981261, r_ui=4, est=4.090783408766608, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=38447, r_ui=4, est=4.459693397627645, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=49750, r_ui=5, est=3.8850540811888705, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=24833801, r_ui=4, est=3.9546235905639056, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=39988, r_ui=4, est=4.659882643286502, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=27401883, r_ui=5, est=4.1979558056479584, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=28954189, r_ui=5, est=4.7846358356720735, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=28959148, r_ui=4, est=3.9595676306023617, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=35504431, r_ui=5, est=4.234433008271871, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=153747, r_ui=5, est=4.250243124710671, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=32487612, r_ui=3, est=4.276338081528432, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=7260188, r_ui=5, est=4.270508125503414, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=853510, r_ui=4, est=4.581848514590011, details={'was_impossible': False}),
#  Prediction(uid=1000984, iid=19266169, r_ui=4, est=3.645446181606186, details={'was_impossible': False}),
#  Prediction(uid=1000985, iid=38447, r_ui=3, est=3.9646169592658906, details={'was_impossible': False}),
#  Prediction(uid=1000986, iid=17802724, r_ui=4, est=3.5670924078715642, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=18126198, r_ui=5, est=4.121589633002274, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=23278537, r_ui=4, est=4.3213447721753235, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=12948, r_ui=1, est=3.463786784363754, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=29496076, r_ui=4, est=3.6623562992118996, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=9903, r_ui=4, est=3.257354872644506, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=20170404, r_ui=3, est=3.7922974808186503, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=428, r_ui=3, est=3.368327374606539, details={'was_impossible': False}),
#  Prediction(uid=1001007, iid=375802, r_ui=4, est=4.563273062202727, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=11447921, r_ui=4, est=4.0951896827378995, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=19358975, r_ui=5, est=4.798444835728671, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=91477, r_ui=4, est=3.959336241142588, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=17346698, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=18966806, r_ui=5, est=4.448537554708161, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=15985373, r_ui=4, est=4.207277023316814, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=179780, r_ui=5, est=4.052588572477359, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=12891107, r_ui=4, est=4.205340304963471, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=18966819, r_ui=4, est=4.046522702824014, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=9579634, r_ui=4, est=3.366402817251226, details={'was_impossible': False}),
#  Prediction(uid=1001018, iid=18774980, r_ui=3, est=3.4435825331930094, details={'was_impossible': False}),
#  Prediction(uid=1001018, iid=14781219, r_ui=2, est=3.174088904341866, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=25893709, r_ui=5, est=3.5130939567937514, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=225343, r_ui=4, est=3.945215251048127, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=26893819, r_ui=5, est=3.9736466741455523, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=4101648, r_ui=4, est=3.8007660463581754, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=15796700, r_ui=5, est=4.441939909611683, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=17380041, r_ui=5, est=3.862849388871139, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=11023952, r_ui=3, est=4.030726415549229, details={'was_impossible': False}),
#  Prediction(uid=1001020, iid=28449207, r_ui=5, est=4.498555577683229, details={'was_impossible': False}),
#  Prediction(uid=1001023, iid=31931941, r_ui=4, est=4.520129078907853, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=28374007, r_ui=5, est=4.2225001028221465, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=23272028, r_ui=4, est=4.2249528927975994, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=23513349, r_ui=5, est=4.3831698464680375, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=7763, r_ui=4, est=4.636394285974795, details={'was_impossible': False}),
#  Prediction(uid=1001028, iid=48757, r_ui=5, est=4.150364787889801, details={'was_impossible': False}),
#  Prediction(uid=1001028, iid=6327, r_ui=5, est=4.258307128190094, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=37415, r_ui=5, est=4.013981048426087, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=12957, r_ui=3, est=4.204343480330988, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=362002, r_ui=5, est=4.670611696907841, details={'was_impossible': False}),
#  Prediction(uid=1001030, iid=17333324, r_ui=4, est=4.0460072224554455, details={'was_impossible': False}),
#  Prediction(uid=1001036, iid=5983694, r_ui=5, est=4.398879012797088, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=9517, r_ui=4, est=4.342487043788317, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=28006120, r_ui=5, est=4.137147080851332, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=56454, r_ui=3, est=3.9741454543998302, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=32283133, r_ui=4, est=4.28667514161581, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=20803953, r_ui=3, est=3.9084476707983535, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=15858248, r_ui=4, est=3.645566747346103, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=21981841, r_ui=3, est=3.8262107797769964, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=14280, r_ui=3, est=4.2910752068915015, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=7023148, r_ui=5, est=4.84425766489227, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=5167, r_ui=5, est=4.664941107124614, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=10574666, r_ui=4, est=4.784485506131541, details={'was_impossible': False}),
#  Prediction(uid=1001048, iid=3692, r_ui=3, est=3.4572551086294236, details={'was_impossible': False}),
#  Prediction(uid=1001048, iid=929, r_ui=2, est=3.8334329205047912, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=13477676, r_ui=5, est=3.6970364835872425, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=13547180, r_ui=3, est=4.218735445675911, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=29780253, r_ui=5, est=4.542955689876045, details={'was_impossible': False}),
#  Prediction(uid=1001050, iid=32283133, r_ui=4, est=3.8436635617952533, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=25558608, r_ui=4, est=4.007464683226549, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=2998, r_ui=4, est=3.908297935292923, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=9051270, r_ui=3, est=3.4180218658212453, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=23513349, r_ui=3, est=4.101868982874182, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=2213661, r_ui=4, est=3.792752308625637, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=186074, r_ui=4, est=4.8663946585736095, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=34076952, r_ui=5, est=4.280463993303307, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=18170143, r_ui=4, est=4.522000386608702, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=32758901, r_ui=5, est=4.721433429525663, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=31451186, r_ui=5, est=4.4501189833891175, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=8520610, r_ui=3, est=4.347375871520144, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=15730101, r_ui=3, est=4.305548280370921, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=15881, r_ui=5, est=4.400275766366332, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=3, r_ui=5, est=4.4924701331777905, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=13596166, r_ui=4, est=4.033447770670212, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=12823329, r_ui=5, est=4.616419832510403, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=3, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=27422533, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=28458598, r_ui=5, est=3.3766758682305826, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=27883214, r_ui=2, est=3.367066226129274, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=32498973, r_ui=4, est=3.241520678878055, details={'was_impossible': False}),
#  Prediction(uid=1001066, iid=56627, r_ui=5, est=3.343062697342451, details={'was_impossible': False}),
#  Prediction(uid=1001066, iid=31823677, r_ui=5, est=4.647174651493078, details={'was_impossible': False}),
#  Prediction(uid=1001072, iid=7445, r_ui=4, est=4.381201571641396, details={'was_impossible': False}),
#  Prediction(uid=1001073, iid=23093367, r_ui=4, est=4.497466288553801, details={'was_impossible': False}),
#  ...]

# %%
from surprise import accuracy

rmse = accuracy.rmse(svd_predictions)
mae = accuracy.mae(svd_predictions)
                     
print(rmse, mae)
# Out:
# RMSE: 0.8259
# MAE:  0.6458
# 0.8259326543219302 0.6458324731790988

# %%
from surprise import NormalPredictor

# инициализируем состояние генератора, это необходимо для получения
# одной и той же последовательности случайных чисел, только в учебных целях
np.random.seed(0)

random_model = NormalPredictor()

random_model.fit(surprise_train_set)
random_predictions = random_model.test(surprise_test_set)
random_predictions
# Out:
# [Prediction(uid=1000003, iid=25893709, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000005, iid=34076952, r_ui=5, est=4.3272637894387875, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=18812405, r_ui=3, est=4.878539300898058, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=7445, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=29868610, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=18774964, r_ui=4, est=3.014834713646897, details={'was_impossible': False}),
#  Prediction(uid=1000006, iid=24817626, r_ui=3, est=4.851241808254272, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=24453082, r_ui=3, est=3.8017772802542478, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=28257707, r_ui=4, est=3.8476438181957398, details={'was_impossible': False}),
#  Prediction(uid=1000007, iid=168642, r_ui=5, est=4.3372123215973, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=31226744, r_ui=4, est=4.083237056676358, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=40440, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=8354134, r_ui=4, est=4.671113083791016, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=5, r_ui=5, est=4.0619241528739565, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=92367, r_ui=3, est=4.368907172615822, details={'was_impossible': False}),
#  Prediction(uid=1000009, iid=13154150, r_ui=4, est=4.263918469719347, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=37415, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=7093952, r_ui=3, est=3.750515286054096, details={'was_impossible': False}),
#  Prediction(uid=1000019, iid=13496, r_ui=2, est=4.244284343230098, details={'was_impossible': False}),
#  Prediction(uid=1000020, iid=38447, r_ui=3, est=3.132203455221968, details={'was_impossible': False}),
#  Prediction(uid=1000020, iid=5203, r_ui=4, est=1.5134861728164983, details={'was_impossible': False}),
#  Prediction(uid=1000023, iid=5094, r_ui=3, est=4.568763441091694, details={'was_impossible': False}),
#  Prediction(uid=1000023, iid=7260188, r_ui=5, est=4.7696318194113205, details={'was_impossible': False}),
#  Prediction(uid=1000025, iid=29056083, r_ui=3, est=3.2388517693285674, details={'was_impossible': False}),
#  Prediction(uid=1000032, iid=17333223, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=28305, r_ui=1, est=2.5602623720221134, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=14942, r_ui=5, est=3.98959042061936, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=2247142, r_ui=3, est=3.767641423912778, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=23164983, r_ui=1, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=897363, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=13812, r_ui=2, est=4.093626319918918, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=6288, r_ui=2, est=4.306307107490855, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=7670, r_ui=4, est=3.1001033970259577, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=5060378, r_ui=4, est=2.05867570137411, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=6327, r_ui=1, est=3.614498459061131, details={'was_impossible': False}),
#  Prediction(uid=1000036, iid=5470, r_ui=5, est=4.094961719557067, details={'was_impossible': False}),
#  Prediction(uid=1000037, iid=12394068, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000038, iid=14864, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000040, iid=20564, r_ui=5, est=3.5769439079648615, details={'was_impossible': False}),
#  Prediction(uid=1000043, iid=17235026, r_ui=5, est=3.657955389671404, details={'was_impossible': False}),
#  Prediction(uid=1000043, iid=46756, r_ui=4, est=2.9469233507215695, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=17607850, r_ui=5, est=2.592989118757509, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=29991719, r_ui=5, est=2.3202461171888724, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=17607848, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=20448515, r_ui=5, est=3.4603915083332977, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=13596809, r_ui=5, est=3.5285913762484387, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=91477, r_ui=5, est=2.7523198735975494, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=47212, r_ui=5, est=4.686789256895975, details={'was_impossible': False}),
#  Prediction(uid=1000044, iid=29863848, r_ui=4, est=2.408259084097402, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=13596809, r_ui=5, est=3.7432910916621873, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=15731779, r_ui=5, est=3.092785068102444, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=24485589, r_ui=5, est=4.314634615396159, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=27827203, r_ui=5, est=3.459292964561227, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=7896527, r_ui=4, est=2.821077415130427, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=7664334, r_ui=5, est=3.919139199148344, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=23308084, r_ui=5, est=4.354108790077431, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=18798983, r_ui=5, est=4.009369449306497, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=18045891, r_ui=4, est=4.234188592618667, details={'was_impossible': False}),
#  Prediction(uid=1000046, iid=20448515, r_ui=5, est=3.3416052085730144, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=20613470, r_ui=4, est=3.6003692759167585, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=9969571, r_ui=4, est=3.3052667377119795, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=10025305, r_ui=4, est=3.603406827206963, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=18335634, r_ui=5, est=3.171220363387759, details={'was_impossible': False}),
#  Prediction(uid=1000051, iid=23437156, r_ui=5, est=2.3011781616643514, details={'was_impossible': False}),
#  Prediction(uid=1000054, iid=8683812, r_ui=2, est=4.115044186682639, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=9409458, r_ui=3, est=3.5631719299309164, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=6654313, r_ui=3, est=2.3927278626585835, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=29056083, r_ui=3, est=4.386933340087829, details={'was_impossible': False}),
#  Prediction(uid=1000055, iid=27695, r_ui=4, est=3.0815116493710866, details={'was_impossible': False}),
#  Prediction(uid=1000056, iid=25111004, r_ui=5, est=3.9954853185307964, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=25489625, r_ui=5, est=4.640673619944019, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=28458598, r_ui=5, est=4.068887161873445, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=432, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=56616, r_ui=4, est=2.7694413674358236, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=5439, r_ui=5, est=4.329345131172314, details={'was_impossible': False}),
#  Prediction(uid=1000060, iid=3447, r_ui=3, est=3.293499917697811, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=34111673, r_ui=4, est=3.116290243688069, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=2906039, r_ui=3, est=3.3944596982228377, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=34189556, r_ui=5, est=3.649142137883912, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=27406704, r_ui=2, est=3.99950611083166, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=31111142, r_ui=4, est=2.835829092166242, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=33280872, r_ui=4, est=4.804304721662418, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=18774964, r_ui=5, est=4.389677598257327, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=33230889, r_ui=5, est=2.4822484720481706, details={'was_impossible': False}),
#  Prediction(uid=1000065, iid=32148091, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000069, iid=22886868, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000069, iid=15790883, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000070, iid=29638254, r_ui=4, est=3.7745578596829086, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=2165, r_ui=5, est=2.9257713742417737, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=3181564, r_ui=3, est=4.950679845573587, details={'was_impossible': False}),
#  Prediction(uid=1000076, iid=30008702, r_ui=5, est=3.561841801830047, details={'was_impossible': False}),
#  Prediction(uid=1000077, iid=17333174, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000084, iid=23168277, r_ui=4, est=4.144437157309082, details={'was_impossible': False}),
#  Prediction(uid=1000084, iid=2372, r_ui=3, est=4.876539410005759, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=4214, r_ui=4, est=4.285539620835493, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=268275, r_ui=3, est=4.6192189010756115, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=20454672, r_ui=4, est=3.9559958966551663, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29864343, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=25893709, r_ui=3, est=4.066914073015997, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=26154406, r_ui=3, est=4.329009478666226, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=77477, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=760924, r_ui=4, est=2.6618378439742494, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=8755776, r_ui=3, est=2.7354650714935875, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29780253, r_ui=5, est=4.869638872657606, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=15791085, r_ui=3, est=2.828231828415116, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=29496076, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000085, iid=25150798, r_ui=3, est=3.551892564389488, details={'was_impossible': False}),
#  Prediction(uid=1000086, iid=28815474, r_ui=4, est=3.2338116221611592, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=12969140, r_ui=2, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=9516, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000091, iid=1, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=32075671, r_ui=4, est=4.809276629103179, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=22918050, r_ui=3, est=3.1254099967171767, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=30333938, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=24445517, r_ui=4, est=3.6906360607856428, details={'was_impossible': False}),
#  Prediction(uid=1000093, iid=18140047, r_ui=4, est=4.710577061516628, details={'was_impossible': False}),
#  Prediction(uid=1000114, iid=87745, r_ui=3, est=4.848539220554778, details={'was_impossible': False}),
#  Prediction(uid=1000117, iid=16143347, r_ui=3, est=3.798296787958133, details={'was_impossible': False}),
#  Prediction(uid=1000118, iid=1582996, r_ui=4, est=4.53109021126699, details={'was_impossible': False}),
#  Prediction(uid=1000122, iid=102868, r_ui=4, est=4.824675900072583, details={'was_impossible': False}),
#  Prediction(uid=1000122, iid=89717, r_ui=4, est=4.304652093645908, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=18774964, r_ui=5, est=2.898475213151232, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=25558608, r_ui=3, est=4.230154673407554, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=11447921, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=5246, r_ui=4, est=3.2842026523779904, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=27774758, r_ui=4, est=3.803418649456394, details={'was_impossible': False}),
#  Prediction(uid=1000126, iid=25489625, r_ui=4, est=3.5313742856652794, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=6136509, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=11275, r_ui=3, est=4.5865582088310815, details={'was_impossible': False}),
#  Prediction(uid=1000127, iid=5948907, r_ui=4, est=4.33422368620006, details={'was_impossible': False}),
#  Prediction(uid=1000128, iid=18635622, r_ui=3, est=3.2124103852551213, details={'was_impossible': False}),
#  Prediction(uid=1000128, iid=11970747, r_ui=4, est=4.459791531876766, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=13497, r_ui=4, est=3.3034828811494266, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=2, r_ui=5, est=3.97631977102606, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=102733, r_ui=5, est=3.340153146079704, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=10664113, r_ui=3, est=4.5905014345861765, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=5096, r_ui=4, est=4.4953708744023615, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=47212, r_ui=5, est=3.747523005109761, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=5, r_ui=5, est=4.323309170241526, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=15881, r_ui=5, est=2.904515321970465, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=184655, r_ui=4, est=2.52511151344562, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=3, r_ui=5, est=4.364646668452014, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=184661, r_ui=4, est=4.104798995073185, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=17571466, r_ui=4, est=4.551053476010009, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=29875363, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=34466922, r_ui=2, est=4.8458975829029, details={'was_impossible': False}),
#  Prediction(uid=1000135, iid=6, r_ui=5, est=3.076248478765911, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=29437949, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=3087, r_ui=2, est=2.6921863030463165, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=32102, r_ui=3, est=3.5061906070446205, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=19288043, r_ui=5, est=3.880970365231428, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=10874177, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000140, iid=13497818, r_ui=4, est=3.2363841895460412, details={'was_impossible': False}),
#  Prediction(uid=1000141, iid=32148570, r_ui=5, est=3.15855541517152, details={'was_impossible': False}),
#  Prediction(uid=1000143, iid=12898, r_ui=3, est=3.852185205790742, details={'was_impossible': False}),
#  Prediction(uid=1000144, iid=38447, r_ui=5, est=3.3138249992980233, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=34273236, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=32585, r_ui=3, est=2.9170256713829295, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29780253, r_ui=5, est=2.8526758429949064, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29430049, r_ui=3, est=3.5288336338382833, details={'was_impossible': False}),
#  Prediction(uid=1000145, iid=29868610, r_ui=3, est=3.471462863365074, details={'was_impossible': False}),
#  Prediction(uid=1000146, iid=1255781, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000146, iid=10929, r_ui=4, est=4.85060570454964, details={'was_impossible': False}),
#  Prediction(uid=1000148, iid=102868, r_ui=5, est=4.0294107988805195, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=34928122, r_ui=5, est=2.778388507562469, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=16101135, r_ui=4, est=4.750505923009004, details={'was_impossible': False}),
#  Prediction(uid=1000150, iid=14996, r_ui=5, est=2.9929797459999787, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=29923707, r_ui=4, est=2.4741235000785715, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=31450852, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=30025336, r_ui=4, est=4.247976382842722, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=18806259, r_ui=3, est=4.823391661970328, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=13262783, r_ui=5, est=4.249677181489225, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=26114463, r_ui=5, est=4.762385166886071, details={'was_impossible': False}),
#  Prediction(uid=1000153, iid=29236299, r_ui=5, est=3.3256900059222327, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=402093, r_ui=4, est=2.9605581288933926, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=28695, r_ui=4, est=4.595419081616871, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=9496240, r_ui=2, est=3.1804974759735587, details={'was_impossible': False}),
#  Prediction(uid=1000161, iid=77507, r_ui=3, est=3.2889839133992886, details={'was_impossible': False}),
#  Prediction(uid=1000163, iid=9969571, r_ui=3, est=3.5119570883692894, details={'was_impossible': False}),
#  Prediction(uid=1000165, iid=33897359, r_ui=3, est=3.9626456648457906, details={'was_impossible': False}),
#  Prediction(uid=1000175, iid=31450908, r_ui=4, est=3.6087037168960747, details={'was_impossible': False}),
#  Prediction(uid=1000175, iid=26114463, r_ui=5, est=2.6359289088972044, details={'was_impossible': False}),
#  Prediction(uid=1000178, iid=10964, r_ui=5, est=3.3327476249869186, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=18812405, r_ui=4, est=1.827518481131008, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=25074850, r_ui=4, est=4.541715985988705, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=15818107, r_ui=4, est=2.419540495695194, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=22318578, r_ui=5, est=2.893727808332982, details={'was_impossible': False}),
#  Prediction(uid=1000182, iid=38447, r_ui=4, est=3.9956946343593107, details={'was_impossible': False}),
#  Prediction(uid=1000183, iid=30821598, r_ui=3, est=3.2413309946673947, details={'was_impossible': False}),
#  Prediction(uid=1000187, iid=26114463, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000187, iid=10614, r_ui=4, est=2.7141489695298637, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=29397486, r_ui=5, est=4.200439207292968, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=17738800, r_ui=4, est=3.9085624851870837, details={'was_impossible': False}),
#  Prediction(uid=1000191, iid=5960325, r_ui=5, est=2.8330243567463294, details={'was_impossible': False}),
#  Prediction(uid=1000195, iid=15798797, r_ui=3, est=4.444572801090535, details={'was_impossible': False}),
#  Prediction(uid=1000195, iid=4671, r_ui=4, est=3.7825409531365013, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=34121119, r_ui=3, est=4.681358446129528, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=29496453, r_ui=5, est=4.73063150185637, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=3431, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=4894, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000196, iid=10929, r_ui=4, est=3.5942325619518494, details={'was_impossible': False}),
#  Prediction(uid=1000199, iid=280412, r_ui=5, est=3.717909377675615, details={'was_impossible': False}),
#  Prediction(uid=1000199, iid=657034, r_ui=4, est=4.9937541959940255, details={'was_impossible': False}),
#  Prediction(uid=1000201, iid=38447, r_ui=4, est=4.570330936646619, details={'was_impossible': False}),
#  Prediction(uid=1000203, iid=166997, r_ui=5, est=4.555912874045924, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=21611, r_ui=3, est=2.405345214418727, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=7959038, r_ui=5, est=3.922813319963878, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=2767793, r_ui=5, est=3.242790777263485, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=24861, r_ui=5, est=4.2127053803479235, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=9717, r_ui=5, est=3.852473081768864, details={'was_impossible': False}),
#  Prediction(uid=1000204, iid=537094, r_ui=3, est=4.813215769112751, details={'was_impossible': False}),
#  Prediction(uid=1000207, iid=85812, r_ui=2, est=4.248238979420495, details={'was_impossible': False}),
#  Prediction(uid=1000207, iid=27037, r_ui=1, est=4.695209785411196, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=345627, r_ui=5, est=3.5015842718218124, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=17724774, r_ui=4, est=3.0461168976539117, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=31931941, r_ui=4, est=3.555293404697617, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=23719270, r_ui=3, est=3.92977424829405, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=136251, r_ui=5, est=4.307249638859422, details={'was_impossible': False}),
#  Prediction(uid=1000209, iid=1, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000214, iid=5107, r_ui=5, est=3.9057285210227617, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=22918050, r_ui=4, est=3.035160819328685, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=16248068, r_ui=4, est=3.6163377315586396, details={'was_impossible': False}),
#  Prediction(uid=1000222, iid=18635016, r_ui=4, est=3.504274160838617, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=95382, r_ui=3, est=4.4047500763771135, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=23127048, r_ui=4, est=2.4779100314715343, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=23093367, r_ui=5, est=4.006267846804895, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=15732712, r_ui=3, est=4.095111852189015, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=10210, r_ui=5, est=4.167215004364472, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=6, r_ui=4, est=3.3768647886655736, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=29396738, r_ui=5, est=3.719298043419566, details={'was_impossible': False}),
#  Prediction(uid=1000227, iid=17167166, r_ui=3, est=2.5891369490306873, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=32075671, r_ui=5, est=3.4759530280475714, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=32905343, r_ui=3, est=3.4287494776111282, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=33984056, r_ui=3, est=4.342406588346136, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=34114362, r_ui=4, est=2.8443732975200655, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=31123261, r_ui=4, est=4.690322021189244, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=33843362, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=7093952, r_ui=4, est=1.9736962666569, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=23282249, r_ui=4, est=4.352133489090587, details={'was_impossible': False}),
#  Prediction(uid=1000230, iid=29749085, r_ui=4, est=4.590953770013574, details={'was_impossible': False}),
#  Prediction(uid=1000231, iid=28390369, r_ui=3, est=3.3386372813059864, details={'was_impossible': False}),
#  Prediction(uid=1000231, iid=8909152, r_ui=3, est=3.5674682504700166, details={'was_impossible': False}),
#  Prediction(uid=1000234, iid=9440324, r_ui=4, est=3.819381933696297, details={'was_impossible': False}),
#  Prediction(uid=1000234, iid=15745753, r_ui=4, est=3.6622543297557746, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=29906980, r_ui=3, est=3.6515618500393345, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=32388712, r_ui=3, est=2.349084124225956, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30687041, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30555488, r_ui=4, est=4.974658997689822, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30244626, r_ui=3, est=3.171012673337785, details={'was_impossible': False}),
#  Prediction(uid=1000236, iid=30259893, r_ui=3, est=2.548772809127595, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=28390369, r_ui=2, est=4.442465398891025, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=8492768, r_ui=4, est=3.397376901007674, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=33984056, r_ui=4, est=4.081245302543604, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=12262741, r_ui=3, est=3.6417332242629543, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=25251757, r_ui=3, est=4.604894011041524, details={'was_impossible': False}),
#  Prediction(uid=1000239, iid=18007564, r_ui=5, est=4.607952893895821, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=25663717, r_ui=4, est=3.254637525905192, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=12088102, r_ui=5, est=2.6279132700640524, details={'was_impossible': False}),
#  Prediction(uid=1000240, iid=30724132, r_ui=3, est=2.4377574488405536, details={'was_impossible': False}),
#  Prediction(uid=1000254, iid=23731881, r_ui=5, est=4.527564835644196, details={'was_impossible': False}),
#  Prediction(uid=1000254, iid=853510, r_ui=4, est=2.813238606046541, details={'was_impossible': False}),
#  Prediction(uid=1000256, iid=38315, r_ui=4, est=3.4630935031023924, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=31309, r_ui=3, est=3.377819529831782, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=900682, r_ui=5, est=3.8959049484451254, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=386286, r_ui=4, est=2.1010914656885173, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=267102, r_ui=4, est=4.125860878915301, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=34, r_ui=5, est=4.445158170425264, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=18512, r_ui=5, est=4.030240546266636, details={'was_impossible': False}),
#  Prediction(uid=1000266, iid=15241, r_ui=5, est=3.649777050417585, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=30688435, r_ui=5, est=4.038794918315867, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=31451186, r_ui=4, est=4.326205352235689, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=6345760, r_ui=4, est=1.304247068322224, details={'was_impossible': False}),
#  Prediction(uid=1000269, iid=32388712, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=32439, r_ui=2, est=4.317674853964669, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=17137623, r_ui=5, est=3.324372284960565, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=32445, r_ui=1, est=3.573488500217757, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=15777797, r_ui=5, est=4.416431773052444, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=16431, r_ui=2, est=3.8353668235966585, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=228221, r_ui=2, est=2.0111420921962497, details={'was_impossible': False}),
#  Prediction(uid=1000277, iid=28321033, r_ui=2, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=51606, r_ui=5, est=3.8406675545392246, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=12395, r_ui=1, est=4.9180185777998116, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=50466, r_ui=3, est=3.286601830474008, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=21027, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=141526, r_ui=4, est=4.218821530742164, details={'was_impossible': False}),
#  Prediction(uid=1000292, iid=4796, r_ui=5, est=4.526101758771035, details={'was_impossible': False}),
#  Prediction(uid=1000293, iid=960, r_ui=4, est=2.950067229949129, details={'was_impossible': False}),
#  Prediction(uid=1000293, iid=20170404, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=140974, r_ui=5, est=4.6032546250437765, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=15704307, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000299, iid=13891, r_ui=5, est=3.3475455129961693, details={'was_impossible': False}),
#  Prediction(uid=1000301, iid=178788, r_ui=5, est=3.48766565408431, details={'was_impossible': False}),
#  Prediction(uid=1000305, iid=23301545, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000306, iid=27274207, r_ui=4, est=2.9360014656862807, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=17607850, r_ui=5, est=3.81645765333153, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=15283043, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=17607848, r_ui=5, est=4.0391043912379105, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=20448515, r_ui=4, est=4.501433451622393, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=13596809, r_ui=5, est=3.5653937859757403, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=11918, r_ui=4, est=4.298583056236205, details={'was_impossible': False}),
#  Prediction(uid=1000319, iid=15731779, r_ui=5, est=2.7011241602202354, details={'was_impossible': False}),
#  Prediction(uid=1000321, iid=23341862, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=23395680, r_ui=5, est=3.833403941163704, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=13619, r_ui=4, est=3.2979132095852224, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=13618, r_ui=4, est=4.580925526610854, details={'was_impossible': False}),
#  Prediction(uid=1000324, iid=3657138, r_ui=2, est=3.5070146106909816, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=16160797, r_ui=4, est=2.6747012933418004, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=11777020, r_ui=4, est=2.662830244654578, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=9572203, r_ui=5, est=4.6070229633805795, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=19101283, r_ui=4, est=3.7939488032256854, details={'was_impossible': False}),
#  Prediction(uid=1000325, iid=1991039, r_ui=4, est=3.818599696650327, details={'was_impossible': False}),
#  Prediction(uid=1000327, iid=7613, r_ui=5, est=4.97287268938552, details={'was_impossible': False}),
#  Prediction(uid=1000327, iid=1885, r_ui=5, est=2.8723444781634444, details={'was_impossible': False}),
#  Prediction(uid=1000333, iid=25740412, r_ui=4, est=3.249796912262484, details={'was_impossible': False}),
#  Prediction(uid=1000335, iid=8752885, r_ui=4, est=3.579275433256182, details={'was_impossible': False}),
#  Prediction(uid=1000335, iid=30688013, r_ui=5, est=4.035890214446072, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=28187230, r_ui=4, est=3.905810176890568, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=149267, r_ui=5, est=3.672643433380175, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=43615, r_ui=3, est=3.8872733737245984, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=14942, r_ui=3, est=3.843750246460509, details={'was_impossible': False}),
#  Prediction(uid=1000339, iid=32692, r_ui=4, est=3.2603476855187328, details={'was_impossible': False}),
#  Prediction(uid=1000349, iid=83143, r_ui=5, est=3.1713664224185014, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=28006120, r_ui=3, est=4.207552372981604, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=16160797, r_ui=4, est=3.097121746016391, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=38447, r_ui=4, est=2.8432558200047766, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=18214414, r_ui=3, est=3.6484373288300427, details={'was_impossible': False}),
#  Prediction(uid=1000354, iid=18081809, r_ui=4, est=3.79576525444132, details={'was_impossible': False}),
#  Prediction(uid=1000360, iid=131359, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000361, iid=1, r_ui=4, est=3.2745484206513567, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=10507293, r_ui=4, est=4.844736338553618, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=18172471, r_ui=5, est=4.657917294377854, details={'was_impossible': False}),
#  Prediction(uid=1000367, iid=16248068, r_ui=5, est=2.8131569529898535, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=9004758, r_ui=4, est=4.6827518552766705, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=16178, r_ui=5, est=2.8179822651409454, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=3678651, r_ui=4, est=1.4123148730770816, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=6318426, r_ui=5, est=4.5236965797387, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=649514, r_ui=5, est=2.2729674854512054, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=830502, r_ui=5, est=4.375644685475614, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=136814, r_ui=5, est=3.2942613941592946, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=202372, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=12862611, r_ui=5, est=4.964074086894526, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=32075671, r_ui=5, est=3.514002477718406, details={'was_impossible': False}),
#  Prediction(uid=1000376, iid=7445, r_ui=5, est=3.2906152769438237, details={'was_impossible': False}),
#  Prediction(uid=1000381, iid=31360, r_ui=5, est=2.789210593819329, details={'was_impossible': False}),
#  Prediction(uid=1000381, iid=3030779, r_ui=5, est=3.5258774683222853, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=7670, r_ui=4, est=3.6788668767930797, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=813214, r_ui=3, est=3.598509037124422, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=67035, r_ui=3, est=4.095299857397434, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=46756, r_ui=4, est=4.497210439875639, details={'was_impossible': False}),
#  Prediction(uid=1000383, iid=1662160, r_ui=4, est=4.279144440747514, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=22151696, r_ui=1, est=3.217910127683438, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=18619684, r_ui=4, est=2.576054377917634, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=6900, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=18003300, r_ui=1, est=3.2890797592521923, details={'was_impossible': False}),
#  Prediction(uid=1000385, iid=5297, r_ui=4, est=3.3244818409857455, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=6496815, r_ui=4, est=3.4493988556024737, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=983546, r_ui=4, est=2.1899028011724653, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=9625608, r_ui=3, est=3.490574681283575, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=3398625, r_ui=3, est=3.488972241850972, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=43615, r_ui=3, est=4.537072814540979, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=365672, r_ui=4, est=4.611485905512163, details={'was_impossible': False}),
#  Prediction(uid=1000387, iid=16142053, r_ui=3, est=3.949584336439086, details={'was_impossible': False}),
#  Prediction(uid=1000388, iid=27126, r_ui=4, est=4.833862576723876, details={'was_impossible': False}),
#  Prediction(uid=1000390, iid=23692271, r_ui=5, est=4.269912247917007, details={'was_impossible': False}),
#  Prediction(uid=1000390, iid=32560066, r_ui=5, est=3.9310493913565074, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=23203106, r_ui=1, est=4.099324810215684, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=2956, r_ui=2, est=3.764335525054949, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=17791477, r_ui=3, est=3.569776233884296, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=92303, r_ui=4, est=3.6908931604236668, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=34484, r_ui=4, est=2.871214904441838, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=890, r_ui=2, est=4.213198082554966, details={'was_impossible': False}),
#  Prediction(uid=1000393, iid=17199504, r_ui=2, est=2.999736798442867, details={'was_impossible': False}),
#  Prediction(uid=1000399, iid=687278, r_ui=5, est=4.747903129805572, details={'was_impossible': False}),
#  Prediction(uid=1000399, iid=34114362, r_ui=4, est=3.7083056575931947, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=33280872, r_ui=4, est=3.993150548057433, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=30364190, r_ui=5, est=4.416522288650082, details={'was_impossible': False}),
#  Prediction(uid=1000403, iid=27362503, r_ui=4, est=4.558945598912767, details={'was_impossible': False}),
#  Prediction(uid=1000404, iid=8490112, r_ui=4, est=2.449491249858121, details={'was_impossible': False}),
#  Prediction(uid=1000404, iid=2696, r_ui=4, est=3.7488522458134645, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=7076706, r_ui=4, est=4.784631578557722, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=17802747, r_ui=3, est=2.328025182954212, details={'was_impossible': False}),
#  Prediction(uid=1000405, iid=8667848, r_ui=5, est=4.314994754840998, details={'was_impossible': False}),
#  Prediction(uid=1000417, iid=14185, r_ui=5, est=1.7968751984404938, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=31450852, r_ui=3, est=2.9717402639612924, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=12666103, r_ui=3, est=3.9827988489493484, details={'was_impossible': False}),
#  Prediction(uid=1000443, iid=28962906, r_ui=5, est=2.3674625263666713, details={'was_impossible': False}),
#  Prediction(uid=1000447, iid=43615, r_ui=5, est=3.0069903933911126, details={'was_impossible': False}),
#  Prediction(uid=1000447, iid=23277298, r_ui=4, est=2.5436174784934362, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=34273236, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=18693763, r_ui=3, est=4.102468678265845, details={'was_impossible': False}),
#  Prediction(uid=1000449, iid=28187230, r_ui=3, est=4.486509260816128, details={'was_impossible': False}),
#  Prediction(uid=1000456, iid=32326398, r_ui=4, est=3.7338251305164833, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=18798983, r_ui=2, est=3.6092393489645045, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=25883848, r_ui=5, est=2.405804329613088, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=17927395, r_ui=5, est=3.6679268789934363, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=28587957, r_ui=5, est=3.220436696146499, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=1420, r_ui=3, est=4.76342688201395, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=23308084, r_ui=2, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=27161156, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=26893819, r_ui=5, est=4.758308420064469, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=25988934, r_ui=4, est=3.3755900594081725, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=27213168, r_ui=5, est=2.8827575313261855, details={'was_impossible': False}),
#  Prediction(uid=1000457, iid=16096824, r_ui=4, est=4.67647305518692, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=500657, r_ui=3, est=4.285469513618634, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=27066722, r_ui=3, est=2.2609165156063806, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=374494, r_ui=3, est=4.284696764003076, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=30259041, r_ui=4, est=4.722071172621173, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=31125554, r_ui=2, est=4.002136092009676, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=12998057, r_ui=4, est=3.769671072280057, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=853510, r_ui=3, est=3.1764586975363125, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=61904, r_ui=3, est=2.567723775768793, details={'was_impossible': False}),
#  Prediction(uid=1000463, iid=24856069, r_ui=3, est=4.708520479749506, details={'was_impossible': False}),
#  Prediction(uid=1000466, iid=34466922, r_ui=4, est=3.651465163311538, details={'was_impossible': False}),
#  Prediction(uid=1000466, iid=830502, r_ui=4, est=3.7235428612553627, details={'was_impossible': False}),
#  Prediction(uid=1000476, iid=18869970, r_ui=3, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000476, iid=39999, r_ui=5, est=4.598188498043909, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=14384, r_ui=5, est=4.299315872498425, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=84133, r_ui=3, est=4.0813488172178, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=23272028, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=29396738, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=17316770, r_ui=4, est=4.831629900904634, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=68783, r_ui=4, est=4.500738771513999, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=983567, r_ui=3, est=1.9502400327565643, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=27507850, r_ui=4, est=4.063874450302102, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=23174274, r_ui=4, est=3.8220246600343066, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=28187230, r_ui=3, est=4.035510654522559, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=8694522, r_ui=3, est=4.8445318304130485, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=13597728, r_ui=4, est=1.3356092549909753, details={'was_impossible': False}),
#  Prediction(uid=1000480, iid=33151805, r_ui=3, est=3.4035471960533963, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=6310782, r_ui=4, est=4.2031580268509305, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=4961048, r_ui=3, est=3.5011779481499947, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=52635, r_ui=3, est=2.595954084874889, details={'was_impossible': False}),
#  Prediction(uid=1000495, iid=96908, r_ui=4, est=4.7739454487832855, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=6584188, r_ui=3, est=4.209796754492843, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=17838528, r_ui=3, est=3.0207166828674223, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=8680278, r_ui=3, est=4.245951280893951, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=15749186, r_ui=4, est=4.728803597972146, details={'was_impossible': False}),
#  Prediction(uid=1000499, iid=20698530, r_ui=4, est=3.951034276570424, details={'was_impossible': False}),
#  Prediction(uid=1000503, iid=13206900, r_ui=5, est=4.708774740056195, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=5907, r_ui=4, est=4.020558210790567, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=48855, r_ui=5, est=3.5694146737239114, details={'was_impossible': False}),
#  Prediction(uid=1000504, iid=1885, r_ui=5, est=2.8412880295562157, details={'was_impossible': False}),
#  Prediction(uid=1000505, iid=2164457, r_ui=3, est=3.8641160174149483, details={'was_impossible': False}),
#  Prediction(uid=1000505, iid=627055, r_ui=4, est=4.1311149789848125, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=22567177, r_ui=5, est=4.7804905382110245, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=34128219, r_ui=5, est=3.836316267189608, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=386286, r_ui=4, est=4.381819961862393, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=22567184, r_ui=5, est=3.0269028329634606, details={'was_impossible': False}),
#  Prediction(uid=1000506, iid=12725, r_ui=3, est=3.200297278952454, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=6261522, r_ui=4, est=3.84081176961808, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=35439987, r_ui=4, est=2.9411345759924536, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=24763621, r_ui=4, est=4.7275288622666345, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=26135139, r_ui=3, est=4.387264987052636, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=23766634, r_ui=5, est=4.21191566132305, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=33280872, r_ui=5, est=4.268901454984144, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=18660447, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000515, iid=22522202, r_ui=5, est=3.499254573056532, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=136251, r_ui=5, est=1.8484438900254658, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=35504431, r_ui=4, est=4.135885927657281, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=10194157, r_ui=5, est=3.897776027224663, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=11408650, r_ui=5, est=3.4528959124369027, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=23766634, r_ui=5, est=3.0133559775416066, details={'was_impossible': False}),
#  Prediction(uid=1000519, iid=27272506, r_ui=3, est=3.527528787225536, details={'was_impossible': False}),
#  Prediction(uid=1000521, iid=29056083, r_ui=4, est=4.1187718390477555, details={'was_impossible': False}),
#  Prediction(uid=1000521, iid=34121119, r_ui=5, est=3.4669043990177277, details={'was_impossible': False}),
# ...
#  Prediction(uid=1000955, iid=31300, r_ui=5, est=3.7619313961560157, details={'was_impossible': False}),
#  Prediction(uid=1000955, iid=18130, r_ui=4, est=4.66606565221024, details={'was_impossible': False}),
#  Prediction(uid=1000955, iid=17934530, r_ui=5, est=3.432302339818894, details={'was_impossible': False}),
#  Prediction(uid=1000955, iid=31304, r_ui=5, est=3.231681591586091, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=30312891, r_ui=5, est=3.9772517961658025, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=13254289, r_ui=4, est=1.4850860443459775, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=19208103, r_ui=5, est=2.8465000265328033, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=16075962, r_ui=3, est=3.6144510982956835, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=31450852, r_ui=5, est=2.6564737369149904, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=13206760, r_ui=5, est=2.9620823714267246, details={'was_impossible': False}),
#  Prediction(uid=1000956, iid=36381037, r_ui=5, est=3.529854763483846, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=1611656, r_ui=4, est=2.380563433261202, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=29923707, r_ui=5, est=3.559083570675443, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=28374007, r_ui=5, est=3.435982528373275, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=2003625, r_ui=4, est=3.9701976560248715, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=13538873, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=367689, r_ui=4, est=4.110354734492265, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=84151, r_ui=2, est=3.9660594392730086, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=28477789, r_ui=4, est=4.040752259862555, details={'was_impossible': False}),
#  Prediction(uid=1000959, iid=23995491, r_ui=5, est=4.162652718187511, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=27876293, r_ui=4, est=2.9772362375511596, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=24583, r_ui=4, est=3.8366327358744137, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=18774964, r_ui=4, est=4.240171592354859, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=4374400, r_ui=4, est=2.6399224170522726, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=168642, r_ui=4, est=4.7707911218794745, details={'was_impossible': False}),
#  Prediction(uid=1000961, iid=25807, r_ui=3, est=4.976333500214492, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=6582637, r_ui=3, est=3.344412276724002, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=3819326, r_ui=3, est=3.7160431976845594, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=18342317, r_ui=5, est=3.1092459609023226, details={'was_impossible': False}),
#  Prediction(uid=1000965, iid=25944798, r_ui=4, est=4.612365664586988, details={'was_impossible': False}),
#  Prediction(uid=1000967, iid=37415, r_ui=5, est=2.9348519382808265, details={'was_impossible': False}),
#  Prediction(uid=1000967, iid=77203, r_ui=3, est=3.7340138722111957, details={'was_impossible': False}),
#  Prediction(uid=1000973, iid=7735333, r_ui=3, est=3.127606956216126, details={'was_impossible': False}),
#  Prediction(uid=1000973, iid=23492533, r_ui=3, est=3.9945409741316285, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=22749788, r_ui=4, est=2.236438135098064, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=8855321, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=6487308, r_ui=3, est=3.02690815870144, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=7740152, r_ui=3, est=4.003059450988881, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=32758901, r_ui=5, est=3.743498075000266, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=16690, r_ui=5, est=3.219843764569286, details={'was_impossible': False}),
#  Prediction(uid=1000976, iid=23714109, r_ui=4, est=3.100108743217561, details={'was_impossible': False}),
#  Prediction(uid=1000978, iid=1618, r_ui=4, est=4.8381980076428235, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=33149088, r_ui=3, est=3.4451576464178206, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=32487617, r_ui=4, est=4.204364117586481, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=29639736, r_ui=4, est=3.1823199839865715, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=11870085, r_ui=5, est=3.329352747858467, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=8909152, r_ui=5, est=4.3959515529448945, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=34684622, r_ui=5, est=4.832490651634189, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=24583, r_ui=3, est=3.778948804963469, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=11447921, r_ui=4, est=2.5911769432809457, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=23164927, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=2767052, r_ui=5, est=3.12986567884765, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=656876, r_ui=3, est=2.4771569473065824, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=6148028, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=816870, r_ui=3, est=3.5610268217835546, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=257845, r_ui=5, est=2.553243033677148, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=50144, r_ui=5, est=3.2948055714271307, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=29981261, r_ui=4, est=4.296190566957646, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=38447, r_ui=4, est=4.127321493896933, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=49750, r_ui=5, est=3.134458311817074, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=24833801, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=39988, r_ui=4, est=3.449026912641902, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=27401883, r_ui=5, est=2.817214350551663, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=28954189, r_ui=5, est=4.861346302793577, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=28959148, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=35504431, r_ui=5, est=3.167078689350129, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=153747, r_ui=5, est=2.6107786294515516, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=32487612, r_ui=3, est=4.927799665775989, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=7260188, r_ui=5, est=1.9952882067801274, details={'was_impossible': False}),
#  Prediction(uid=1000981, iid=853510, r_ui=4, est=2.777258345146346, details={'was_impossible': False}),
#  Prediction(uid=1000984, iid=19266169, r_ui=4, est=4.8677803682558265, details={'was_impossible': False}),
#  Prediction(uid=1000985, iid=38447, r_ui=3, est=3.8932511425307625, details={'was_impossible': False}),
#  Prediction(uid=1000986, iid=17802724, r_ui=4, est=3.694510193230731, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=18126198, r_ui=5, est=4.282157357278247, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=23278537, r_ui=4, est=3.8004269483848, details={'was_impossible': False}),
#  Prediction(uid=1000992, iid=12948, r_ui=1, est=2.7085942864689327, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=29496076, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=9903, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=20170404, r_ui=3, est=4.141633605902658, details={'was_impossible': False}),
#  Prediction(uid=1001006, iid=428, r_ui=3, est=3.988995391192326, details={'was_impossible': False}),
#  Prediction(uid=1001007, iid=375802, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=11447921, r_ui=4, est=3.6826044032866796, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=19358975, r_ui=5, est=3.698664778927008, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=91477, r_ui=4, est=4.293271504456146, details={'was_impossible': False}),
#  Prediction(uid=1001012, iid=17346698, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=18966806, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=15985373, r_ui=4, est=3.699621730263536, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=179780, r_ui=5, est=4.239771417562055, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=12891107, r_ui=4, est=2.6329445535554528, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=18966819, r_ui=4, est=3.6487385521281697, details={'was_impossible': False}),
#  Prediction(uid=1001013, iid=9579634, r_ui=4, est=3.1453572762538897, details={'was_impossible': False}),
#  Prediction(uid=1001018, iid=18774980, r_ui=3, est=2.9866755925379045, details={'was_impossible': False}),
#  Prediction(uid=1001018, iid=14781219, r_ui=2, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=25893709, r_ui=5, est=3.1910955446898717, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=225343, r_ui=4, est=3.4394738557257414, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=26893819, r_ui=5, est=4.294574504166574, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=4101648, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=15796700, r_ui=5, est=4.404401018215659, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=17380041, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001019, iid=11023952, r_ui=3, est=3.8748472754737833, details={'was_impossible': False}),
#  Prediction(uid=1001020, iid=28449207, r_ui=5, est=4.192498109233369, details={'was_impossible': False}),
#  Prediction(uid=1001023, iid=31931941, r_ui=4, est=4.208585516538986, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=28374007, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=23272028, r_ui=4, est=4.429291967652819, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=23513349, r_ui=5, est=3.8352469973649823, details={'was_impossible': False}),
#  Prediction(uid=1001027, iid=7763, r_ui=4, est=3.0432181373557525, details={'was_impossible': False}),
#  Prediction(uid=1001028, iid=48757, r_ui=5, est=4.178898717355181, details={'was_impossible': False}),
#  Prediction(uid=1001028, iid=6327, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=37415, r_ui=5, est=3.5549769772322732, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=12957, r_ui=3, est=4.449972315276587, details={'was_impossible': False}),
#  Prediction(uid=1001029, iid=362002, r_ui=5, est=4.180522616615376, details={'was_impossible': False}),
#  Prediction(uid=1001030, iid=17333324, r_ui=4, est=4.768758533705892, details={'was_impossible': False}),
#  Prediction(uid=1001036, iid=5983694, r_ui=5, est=3.1792168312110327, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=9517, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=28006120, r_ui=5, est=2.7271984190661005, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=56454, r_ui=3, est=3.597691962126514, details={'was_impossible': False}),
#  Prediction(uid=1001041, iid=32283133, r_ui=4, est=4.839812059295501, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=20803953, r_ui=3, est=4.228720698026262, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=15858248, r_ui=4, est=4.736807598325872, details={'was_impossible': False}),
#  Prediction(uid=1001043, iid=21981841, r_ui=3, est=3.473301891070378, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=14280, r_ui=3, est=3.8747167367660666, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=7023148, r_ui=5, est=3.957646122143956, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=5167, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001047, iid=10574666, r_ui=4, est=4.603836656264655, details={'was_impossible': False}),
#  Prediction(uid=1001048, iid=3692, r_ui=3, est=4.705065754978175, details={'was_impossible': False}),
#  Prediction(uid=1001048, iid=929, r_ui=2, est=3.319115165544669, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=13477676, r_ui=5, est=4.869149063817128, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=13547180, r_ui=3, est=4.160927079367169, details={'was_impossible': False}),
#  Prediction(uid=1001049, iid=29780253, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001050, iid=32283133, r_ui=4, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=25558608, r_ui=4, est=3.653702990107343, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=2998, r_ui=4, est=3.558863153965057, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=9051270, r_ui=3, est=3.122723743650085, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=23513349, r_ui=3, est=3.809187919944792, details={'was_impossible': False}),
#  Prediction(uid=1001053, iid=2213661, r_ui=4, est=3.581995086176149, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=186074, r_ui=4, est=4.28852952984853, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=34076952, r_ui=5, est=3.808247209137382, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=18170143, r_ui=4, est=3.6014572715382798, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=32758901, r_ui=5, est=4.96033502350551, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=31451186, r_ui=5, est=3.05237304858971, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=8520610, r_ui=3, est=4.358659472540501, details={'was_impossible': False}),
#  Prediction(uid=1001056, iid=15730101, r_ui=3, est=3.5592075013292765, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=15881, r_ui=5, est=4.636174413149516, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=3, r_ui=5, est=5, details={'was_impossible': False}),
#  Prediction(uid=1001057, iid=13596166, r_ui=4, est=3.657197429403462, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=12823329, r_ui=5, est=4.366210420169575, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=3, r_ui=5, est=4.1163464096681555, details={'was_impossible': False}),
#  Prediction(uid=1001059, iid=27422533, r_ui=5, est=3.184296567545226, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=28458598, r_ui=5, est=4.175415308112008, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=27883214, r_ui=2, est=4.221467299384858, details={'was_impossible': False}),
#  Prediction(uid=1001062, iid=32498973, r_ui=4, est=4.33937740139275, details={'was_impossible': False}),
#  Prediction(uid=1001066, iid=56627, r_ui=5, est=3.756955654670571, details={'was_impossible': False}),
#  Prediction(uid=1001066, iid=31823677, r_ui=5, est=4.035738442848317, details={'was_impossible': False}),
#  Prediction(uid=1001072, iid=7445, r_ui=4, est=2.852540265843824, details={'was_impossible': False}),
#  Prediction(uid=1001073, iid=23093367, r_ui=4, est=3.604777997728702, details={'was_impossible': False}),
#  ...]

# %%
rmse = accuracy.rmse(random_predictions)
mae = accuracy.mae(random_predictions)
                     
print(rmse, mae)
# Out:
# RMSE: 1.2608
# MAE:  0.9999
# 1.2607921290603934 0.9998705396950534

# %%
events_test
# Out:
#           user_id   item_id  started_at     read_at  is_read  rating  \
# 50        1000003  25893709  2017-10-05  2017-10-17     True       4
# 263       1000005  34076952  2017-10-09  2017-10-24     True       5
# 285       1000006  18812405  2017-08-05  2017-08-19     True       3
# 290       1000006      7445  2017-08-26  2017-08-30     True       4
# 294       1000006  29868610  2017-08-30  2017-09-16     True       4
# ...           ...       ...         ...         ...      ...     ...
# 11751007  1430579  27272506  2017-09-03  2017-10-07     True       3
# 11751058  1430580  22021611  2017-10-05  2017-10-05     True       4
# 11751059  1430580  15749186  2017-10-05  2017-10-18     True       4
# 11751073  1430584  18692431  2017-08-02  2017-08-09     True       3
# 11751078  1430584  23395680  2017-08-09  2017-08-15     True       4
#
#           is_reviewed started_at_month
# 50              False       2017-10-01
# 263             False       2017-10-01
# 285             False       2017-08-01
# 290             False       2017-08-01
# 294             False       2017-08-01
# ...               ...              ...
# 11751007         True       2017-09-01
# 11751058        False       2017-10-01
# 11751059        False       2017-10-01
# 11751073         True       2017-08-01
# 11751078         True       2017-08-01
#
# [424962 rows x 8 columns]

# %%
# получить оценку для пользователя user_id и айтема item_id поможет метод predict
svd_model.predict("1000003","34076952")
# Out:
# Prediction(uid='1000003', iid='34076952', r_ui=None, est=3.9459914088879833, details={'was_impossible': False})

# %%
set(events_test[events_test["user_id"]==1000006]['item_id'].unique())
# Out:
# {7445, 18774964, 18812405, 24817626, 29868610}

# %%
def get_recommendations_svd(user_id, all_items, events, model, include_seen=True, n=5):

    """ возвращает n рекомендаций для user_id """
    
    # получим список идентификаторов всех книг
    all_items = set(events['item_id'].unique())
        
    # учитываем флаг, стоит ли уже прочитанные книги включать в рекомендации
    if include_seen:
        items_to_predict = list(all_items)
    else:
        # получим список книг, которые пользователь уже прочитал ("видел")
        seen_items = set(events[events_test["user_id"]==user_id]['item_id'].unique())
        
        # книги, которые пользователь ещё не читал
        # только их и будем включать в рекомендации
        items_to_predict = list(all_items - seen_items)
    
    # получаем скоры для списка книг, т. е. рекомендации
    predictions = [svd_model.predict(user_id,item_id) for item_id in items_to_predict]
    
    # сортируем рекомендации по убыванию скора и берём только n первых
    recommendations = sorted(predictions, key=lambda x: x.est, reverse=True)[:n]
    
    return pd.DataFrame([(pred.iid, pred.est) for pred in recommendations], columns=["item_id", "score"])

# %%
get_recommendations_svd(1296647, items, events_train, svd_model)
# Out:
#     item_id     score
# 0     24812  5.000000
# 1    323355  4.988212
# 2  30688013  4.975064
# 3  11737700  4.972143
# 4   6898978  4.960511

# %% [markdown]
# # Дополнительная проверка качества рекомендаций

# %%
# выберем произвольного пользователя из тренировочной выборки ("прошлого")
user_id = events_train['user_id'].sample().iat[0]

print(f"user_id: {user_id}")
# Out:
# user_id: 1309190

# %%
print("История (последние события, recent)")
user_history = (
    events_train
    .query("user_id == @user_id")
    .merge(items.set_index("item_id")[["author", "title", "genre_and_votes"]], on="item_id")
)
user_history_to_print = user_history[["author", "title", "started_at", "read_at", "rating", "genre_and_votes"]].tail(10)
display(user_history_to_print)
# Out:
# История (последние события, recent)
#                                                author  \
# 29                                      Sarah J. Maas
# 30                                      Truman Capote
# 31                               T. Coraghessan Boyle
# 32                                     Aaron Hartzler
# 33                             Jennifer L. Armentrout
# 34  Cassandra Clare, Sarah Rees Brennan, Maureen J...
# 35                                  Alexandra Bracken
# 36                             Jennifer L. Armentrout
# 37                                       Rick Riordan
# 38                      Krista Ritchie, Becca Ritchie
#
#                                                 title  started_at     read_at  \
# 29  A Court of Mist and Fury (A Court of Thorns an...  2016-05-29  2016-07-04
# 30                                      In Cold Blood  2015-06-03  2015-06-22
# 31                               The Tortilla Curtain  2015-10-04  2015-10-19
# 32                                        What We Saw  2016-01-31  2016-02-21
# 33                               Opposition (Lux, #5)  2014-08-20  2014-08-23
# 34                                The Bane Chronicles  2015-01-08  2015-02-01
# 35          In The Afterlight (The Darkest Minds, #3)  2014-11-06  2014-11-08
# 36            Beginnings: Obsidian & Onyx (Lux, #1-2)  2014-08-07  2014-08-08
# 37   The Blood of Olympus (The Heroes of Olympus, #5)  2014-11-15  2015-02-15
# 38                     Addicted to You (Addicted, #1)  2016-03-27  2016-03-29
#
#     rating                                    genre_and_votes
# 29       5  {'Fantasy': 10186, 'Romance': 3346, 'Young Adu...
# 30       5  {'Nonfiction': 7191, 'Classics': 4022, 'Crime-...
# 31       3  {'Fiction': 665, 'Contemporary': 76, 'Book Clu...
# 32       5  {'Young Adult': 480, 'Contemporary': 370, 'Mys...
# 33       5  {'Young Adult': 1143, 'Fantasy-Paranormal': 95...
# 34       4             {'Fantasy': 1972, 'Young Adult': 1142}
# 35       5  {'Young Adult': 989, 'Science Fiction-Dystopia...
# 36       4  {'Young Adult': 140, 'Fantasy-Paranormal': 89,...
# 37       4  {'Fantasy': 4774, 'Fantasy-Mythology': 2114, '...
# 38       4  {'New Adult': 1008, 'Romance': 783, 'Contempor...

# %%
print("Рекомендации")
user_recommendations = get_recommendations_svd(user_id, items, events_train, svd_model)
user_recommendations = user_recommendations.merge(items[["item_id", "author", "title", "genre_and_votes"]], on="item_id")
display(user_recommendations)
# Out:
# Рекомендации
#    item_id  score                       author  \
# 0        1      5                 J.K. Rowling
# 1        2      5  J.K. Rowling, Mary GrandPré
# 2        3      5  J.K. Rowling, Mary GrandPré
# 3        5      5  J.K. Rowling, Mary GrandPré
# 4        6      5  J.K. Rowling, Mary GrandPré
#
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Sorcerer's Stone (Harry P...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter and the Goblet of Fire (Harry Pot...
#
#                                      genre_and_votes
# 0  {'Fantasy': 46400, 'Young Adult': 15083, 'Fict...
# 1  {'Fantasy': 46485, 'Young Adult': 15194, 'Fict...
# 2  {'Fantasy': 59818, 'Fiction': 17918, 'Young Ad...
# 3  {'Fantasy': 49784, 'Young Adult': 15393, 'Fict...
# 4  {'Fantasy': 48257, 'Young Adult': 15483, 'Fict...

# %%
user_recommendations
# Out:
#     book_id  score
# 0        13      5
# 1      1111      5
# 2  13633498      5
# 3  33163378      5
# 4   8521879      5

# %% [markdown]
# # Коллаборативная фильтрация: ALS

# %%
import scipy
import sklearn.preprocessing

# перекодируем идентификаторы пользователей: 
# из имеющихся в последовательность 0, 1, 2, ...
user_encoder = sklearn.preprocessing.LabelEncoder()
user_encoder.fit(events["user_id"])
events_train["user_id_enc"] = user_encoder.transform(events_train["user_id"])
events_test["user_id_enc"] = user_encoder.transform(events_test["user_id"])

# перекодируем идентификаторы объектов: 
# из имеющихся в последовательность 0, 1, 2, ...
item_encoder = sklearn.preprocessing.LabelEncoder()
item_encoder.fit(items["item_id"])
items["item_id_enc"] = item_encoder.transform(items["item_id"])

# %%
events_train["item_id_enc"] = item_encoder.transform(events_train["item_id"])
events_test["item_id_enc"] = item_encoder.transform(events_test["item_id"])

# %%
events_train[events_train["item_id"]==7445]
# Out:
#           user_id  item_id  started_at     read_at  is_read  rating  \
# 590       1000020     7445  2017-03-20  2017-03-30     True       3
# 669       1000027     7445  2015-10-28  2015-12-01     True       5
# 3229      1000085     7445  2012-08-04  2012-08-23     True       3
# 9163      1000304     7445  2012-10-31  2012-11-03     True       1
# 9453      1000316     7445  2012-11-21  2013-01-07     True       4
# ...           ...      ...         ...         ...      ...     ...
# 11743759  1430319     7445  2015-05-23  2015-06-20     True       4
# 11745360  1430388     7445  2017-07-30  2017-08-13     True       5
# 11746281  1430416     7445  2012-03-12  2012-03-14     True       5
# 11746398  1430418     7445  2017-02-24  2017-06-20     True       5
# 11751085  1430584     7445  2016-04-24  2016-05-18     True       4
#
#           is_reviewed started_at_month  user_id_enc  item_id_enc
# 590             False       2017-03-01           20          868
# 669             False       2015-10-01           27          868
# 3229            False       2012-08-01           85          868
# 9163            False       2012-10-01          304          868
# 9453            False       2012-11-01          316          868
# ...               ...              ...          ...          ...
# 11743759         True       2015-05-01       430319          868
# 11745360        False       2017-07-01       430388          868
# 11746281        False       2012-03-01       430416          868
# 11746398        False       2017-02-01       430418          868
# 11751085         True       2016-04-01       430584          868
#
# [6470 rows x 10 columns]

# %%
items[items["item_id"]==7445]
# Out:
#          item_id           author             title  \
# 1795375     7445  Jeannette Walls  The Glass Castle
#
#                                                description  \
# 1795375  A tender, moving tale of unconditional love in...
#
#                                            genre_and_votes  num_pages  \
# 1795375  {'Nonfiction': 6451, 'Autobiography-Memoir': 5...        288
#
#          average_rating  ratings_count  text_reviews_count publisher  \
# 1795375            4.24         643450               40143  Scribner
#
#          publication_year country_code language_code     format  is_ebook  \
# 1795375              2006           US           eng  Paperback     False
#
#                isbn         isbn13  \
# 1795375  074324754X  9780743247542
#
#                                       genre_and_votes_dict  \
# 1795375  {'Academic': None, 'Academic-Academia': None, ...
#
#                                 genre_and_votes_str  item_id_enc
# 1795375  Nonfiction 6451, Autobiography-Memoir 5734          868

# %%
# Матрица заняла бы 17 Гб даже для такого относительно небольшого набора данных
(43312*430585)/(1024*1024*1024)
# Out:
# 17.36869804561138

# %%
# создаём sparse-матрицу формата CSR 
events_train["rating"] = events_train["rating"].astype(int)
events_train["user_id_enc"] = events_train["user_id_enc"].astype(int)
events_train["item_id_enc"] = events_train["item_id_enc"].astype(int)
user_item_matrix_train = scipy.sparse.csr_matrix((
    events_train["rating"],
    (events_train['user_id_enc'], events_train['item_id_enc'])),
    dtype=np.int8)

# %%
# Размеры памяти, требуемой для хранения матрицы взаимодействий, уменьшились на два порядка
import sys

sum([sys.getsizeof(i) for i in user_item_matrix_train.data])/1024**3
# Out:
# 0.26370687410235405

# %%
# создадим ALS-модель. Для примера возьмём количество латентных факторов для матриц $P, Q$, равным 50. 
from implicit.als import AlternatingLeastSquares

als_model = AlternatingLeastSquares(factors=50, iterations=50, regularization=0.05, random_state=0)
als_model.fit(user_item_matrix_train)
# Out:
# /home/mle-user/anaconda3/lib/python3.12/site-packages/implicit/gpu/__init__.py:13: UserWarning: CUDA extension is built, but disabling GPU support because of 'Cuda Error: CUDA driver version is insufficient for CUDA runtime version (/home/conda/feedstock_root/build_artifacts/implicit_1724419594932/work/./implicit/gpu/utils.h:71)'
#   warnings.warn(
# /home/mle-user/anaconda3/lib/python3.12/site-packages/implicit/cpu/als.py:95: RuntimeWarning: Intel MKL BLAS is configured to use 2 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'MKL_NUM_THREADS=1' or by callng 'threadpoolctl.threadpool_limits(1, "blas")'. Having MKL use a threadpool can lead to severe performance issues
#   check_blas_config()
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Чтобы получить рекомендации для пользователя с помощью модели ALS, используем такую функцию:
def get_recommendations_als(user_item_matrix, model, user_id, user_encoder, item_encoder, include_seen=True, n=5):
    """
    Возвращает отранжированные рекомендации для заданного пользователя
    """
    user_id_enc = user_encoder.transform([user_id])[0]
    recommendations = model.recommend(
         user_id_enc, 
         user_item_matrix[user_id_enc], 
         filter_already_liked_items=not include_seen,
         N=n)
    recommendations = pd.DataFrame({"item_id_enc": recommendations[0], "score": recommendations[1]})
    recommendations["item_id"] = item_encoder.inverse_transform(recommendations["item_id_enc"])
    
    return recommendations

# %%
get_recommendations_als(user_item_matrix_train, als_model, 1296647, user_encoder, item_encoder, include_seen=True, n=5)
# Out:
#    item_id_enc     score   item_id
# 0        27664  0.900479   9460487
# 1        38878  0.864531  22557272
# 2         1641  0.784560     13496
# 3        29910  0.691176  11870085
# 4         6942  0.679305     99561

# %%
# получаем список всех возможных user_id (перекодированных)
user_ids_encoded = range(len(user_encoder.classes_))

# получаем рекомендации для всех пользователей
als_recommendations = als_model.recommend(
    user_ids_encoded, 
    user_item_matrix_train[user_ids_encoded], 
    filter_already_liked_items=False, N=100)

# %%
# преобразуем полученные рекомендации в табличный формат
item_ids_enc = als_recommendations[0]
als_scores = als_recommendations[1]

als_recommendations = pd.DataFrame({
    "user_id_enc": user_ids_encoded,
    "item_id_enc": item_ids_enc.tolist(), 
    "score": als_scores.tolist()})
als_recommendations = als_recommendations.explode(["item_id_enc", "score"], ignore_index=True)

# приводим типы данных
als_recommendations["item_id_enc"] = als_recommendations["item_id_enc"].astype("int")
als_recommendations["score"] = als_recommendations["score"].astype("float")

# получаем изначальные идентификаторы
als_recommendations["user_id"] = user_encoder.inverse_transform(als_recommendations["user_id_enc"])
als_recommendations["item_id"] = item_encoder.inverse_transform(als_recommendations["item_id_enc"])
als_recommendations = als_recommendations.drop(columns=["user_id_enc", "item_id_enc"])

# %%
als_recommendations.head()
# Out:
#       score  user_id  item_id
# 0  0.990940  1000000        3
# 1  0.896617  1000000    15881
# 2  0.864405  1000000        5
# 3  0.822256  1000000        6
# 4  0.774098  1000000        2

# %%
als_recommendations = als_recommendations[["user_id", "item_id", "score"]]
als_recommendations.to_parquet("als_recommendations.parquet")

# %%
als_recommendations = (
    als_recommendations
    .merge(events_test[["user_id", "item_id", "rating"]]
               .rename(columns={"rating": "rating_test"}), 
           on=["user_id", "item_id"], how="left")
)

# %%
als_recommendations.head()
# Out:
#    user_id  item_id     score  rating_test
# 0  1000000        3  0.990940          NaN
# 1  1000000    15881  0.896617          NaN
# 2  1000000        5  0.864405          NaN
# 3  1000000        6  0.822256          NaN
# 4  1000000        2  0.774098          NaN

# %%
import sklearn.metrics

def compute_ndcg(rating: pd.Series, score: pd.Series, k):

    """ подсчёт ndcg
    rating: истинные оценки
    score: оценки модели
    k: количество айтемов (по убыванию score) для оценки, остальные - отбрасываются
    """
    
    # если кол-во объектов меньше 2, то NDCG - не определена
    if len(rating) < 2:
        return np.nan

    ndcg = sklearn.metrics.ndcg_score(np.asarray([rating.to_numpy()]), np.asarray([score.to_numpy()]), k=k)

    return ndcg

# %%
rating_test_idx = ~als_recommendations["rating_test"].isnull()
rating_test_idx
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 43058495    False
# 43058496    False
# 43058497    False
# 43058498    False
# 43058499    False
# Name: rating_test, Length: 43058500, dtype: bool

# %%
ndcg_at_5_scores = als_recommendations[rating_test_idx].groupby("user_id").apply(lambda x: compute_ndcg(x["rating_test"], x["score"], k=5))
ndcg_at_5_scores
# Out:
# /tmp/ipykernel_2152/732957696.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ndcg_at_5_scores = als_recommendations[rating_test_idx].groupby("user_id").apply(lambda x: compute_ndcg(x["rating_test"], x["score"], k=5))
# user_id
# 1000006    1.0
# 1000007    NaN
# 1000019    NaN
# 1000020    NaN
# 1000023    1.0
#           ...
# 1430558    NaN
# 1430569    1.0
# 1430573    NaN
# 1430578    1.0
# 1430584    NaN
# Length: 48135, dtype: float64

# %%
print(ndcg_at_5_scores.mean())
# Out:
# 0.9759562997103215

# %%
ndcg_at_5_scores
# Out:
# user_id
# 1000006    1.0
# 1000007    NaN
# 1000019    NaN
# 1000020    NaN
# 1000023    1.0
#           ...
# 1430558    NaN
# 1430569    1.0
# 1430573    NaN
# 1430578    1.0
# 1430584    NaN
# Length: 48135, dtype: float64

# %%
17235/48135
# Out:
# 0.3580554689934559

# %%
als_model.similar_items(3)
# Out:
# (array([    3,  1942,     4,     1,     0,     2,  8250, 26800, 23781,
#         18446], dtype=int32),
#  array([0.9999999 , 0.9975803 , 0.9962052 , 0.98827547, 0.982088  ,
#         0.97494876, 0.97159123, 0.90773606, 0.90773606, 0.82279867],
#        dtype=float32))

# %%
als_model.similar_users(20)
# Out:
# (array([    20, 205189, 123595, 241251, 236341, 329941,  48303, 303533,
#         153470, 289638], dtype=int32),
#  array([1.        , 0.8676769 , 0.8359941 , 0.8275909 , 0.8241378 ,
#         0.8222106 , 0.8113861 , 0.81118315, 0.80413705, 0.8035676 ],
#        dtype=float32))

# %% [markdown]
# # === Базовые подходы: контентные рекомендации

# %%
items["genre_and_votes"] = items["genre_and_votes"].apply(eval)
items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 items["genre_and_votes"] = items["genre_and_votes"].apply(eval)
#       2 items
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
def get_genres(items):

    """ 
    извлекает список жанров по всем книгам, 
    подсчитывает долю голосов по каждому их них
    """
    
    genres_counter = {}
    
    for k, v, in items.iterrows():
        genre_and_votes = v["genre_and_votes"]
        if genre_and_votes is None or not isinstance(genre_and_votes, dict):
            continue
        for genre, votes in genre_and_votes.items():
            # увеличиваем счётчик жанров
            try:
                genres_counter[genre] += 1
            except KeyError:
                genres_counter[genre] = 0

    genres = pd.Series(genres_counter, name="votes")
    genres = genres.to_frame()
    genres = genres.reset_index().rename(columns={"index": "name"})
    genres.index.name = "genre_id"
    
    return genres
   
genres = get_genres(items)

# %%
genres
# Out:
#                                     name  votes
# genre_id
# 0               Womens Fiction-Chick Lit   1705
# 1                                Fiction  22440
# 2                               Politics    933
# 3                                  Humor   2101
# 4                              Christian   1482
# ...                                  ...    ...
# 810            German History-Nazi Party      0
# 811                            Favorites      0
# 812       History-Latin American History      0
# 813                     Cryptids-Bigfoot      0
# 814                   Politics-Far Right      0
#
# [815 rows x 2 columns]

# %%
genres["score"] = genres["votes"] / genres["votes"].sum()
genres.sort_values(by="score", ascending=False).head(10)
# Out:
#                                    name  votes     score
# genre_id
# 1                               Fiction  22440  0.106816
# 34                              Romance  11166  0.053151
# 25                              Fantasy  11108  0.052875
# 18                          Young Adult   8614  0.041003
# 5                            Nonfiction   6822  0.032473
# 52                         Contemporary   5518  0.026266
# 16        Historical-Historical Fiction   5497  0.026166
# 20                              Mystery   5110  0.024324
# 33                   Fantasy-Paranormal   4413  0.021006
# 38                             Classics   4373  0.020816

# %%
def get_item2genre_matrix(genres, items):

    genre_names_to_id = genres.reset_index().set_index("name")["genre_id"].to_dict()
    
    # list to build CSR matrix
    genres_csr_data = []
    genres_csr_row_idx = []
    genres_csr_col_idx = []
    
    for item_idx, (k, v) in enumerate(items.iterrows()):
        if v["genre_and_votes"] is None:
            continue
        for genre_name, votes in v["genre_and_votes"].items():
            genre_idx = genre_names_to_id[genre_name]
            genres_csr_data.append(int(votes))
            genres_csr_row_idx.append(item_idx)
            genres_csr_col_idx.append(genre_idx)

    genres_csr = scipy.sparse.csr_matrix((genres_csr_data, (genres_csr_row_idx, genres_csr_col_idx)), shape=(len(items), len(genres)))
    # нормализуем, чтобы сумма оценок принадлежности к жанру была равна 1
    genres_csr = sklearn.preprocessing.normalize(genres_csr, norm='l1', axis=1)
    
    return genres_csr

# %%
# Получим матрицу с весами по жанрам для каждой книги:
items = items.sort_values(by="item_id_enc")
all_items_genres_csr = get_item2genre_matrix(genres, items)

# %%
# Аналогичным образом получим матрицу с весами по жанрам для какого-нибудь пользователя, например, для пользователя с идентификатором 1000010. 
user_id = 1000010
user_events = events_train.query("user_id == @user_id")[["item_id", "rating"]]
user_items = items[items["item_id"].isin(user_events["item_id"])]

user_items_genres_csr = get_item2genre_matrix(genres, user_items)
user_items_genres_csr
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 149 stored elements and shape (22, 815)>

# %%
# вычислим склонность пользователя к жанрам как среднее взвешенное значение популяции на его оценки книг.

# преобразуем пользовательские оценки из списка в вектор-столбец
user_ratings = user_events["rating"].to_numpy() / 5
user_ratings = np.expand_dims(user_ratings, axis=1)

user_items_genres_weighted = user_items_genres_csr.multiply(user_ratings)

user_genres_scores = np.asarray(user_items_genres_weighted.mean(axis=0))

# %%
# выведем список жанров, которые предпочитает пользователь

user_genres = genres.copy()
user_genres["score"] = np.ravel(user_genres_scores)
user_genres = user_genres[user_genres["score"] > 0].sort_values(by=["score"], ascending=False)

user_genres.head(5)
# Out:
#                      name  votes     score
# genre_id
# 1                 Fiction  22440  0.180513
# 38               Classics   4373  0.098675
# 25                Fantasy  11108  0.088185
# 5              Nonfiction   6822  0.044133
# 24        Science Fiction   3595  0.041981

# %%
from sklearn.metrics.pairwise import cosine_similarity

# вычисляем сходство между вектором пользователя и векторами по книгам
similarity_scores = cosine_similarity(all_items_genres_csr, user_genres_scores)

# преобразуем в одномерный массив
similarity_scores = similarity_scores.flatten()
similarity_scores
# Out:
# array([0.55499991, 0.546343  , 0.5726901 , ..., 0.67143461, 0.03420267,
#        0.33994595])

# %%
# получаем индексы top-k (по убыванию значений), по сути, индексы книг (encoded)
k = 5
top_k_indices = np.argsort(similarity_scores)[::-1]
top_k_indices
# Out:
# array([ 4471,  1120, 14087, ..., 32709, 32708, 38761])

# %%
selected_items = items[items["item_id_enc"].isin(top_k_indices)]

with pd.option_context("max_colwidth", 100):
   display(selected_items[["author", "title", "genre_and_votes"]])
# Out:
#                               author  \
# 861044                  J.K. Rowling
# 2083381  J.K. Rowling, Mary GrandPré
# 1584855  J.K. Rowling, Mary GrandPré
# 1028676  J.K. Rowling, Mary GrandPré
# 2251360  J.K. Rowling, Mary GrandPré
# ...                              ...
# 1229539                  Lylah James
# 534649          David       Anderson
# 1541052     Elaine Williams Crockett
# 2251007                 Logan Chance
# 96267              Emily Lloyd-Jones
#
#                                                                 title  \
# 861044      Harry Potter and the Half-Blood Prince (Harry Potter, #6)
# 2083381  Harry Potter and the Order of the Phoenix (Harry Potter, #5)
# 1584855      Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# 1028676   Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# 2251360        Harry Potter and the Goblet of Fire (Harry Potter, #4)
# ...                                                               ...
# 1229539          The Mafia And His Angel: Part 2 (Tainted Hearts, #2)
# 534649                                                    The Remnant
# 1541052                                                    Do Not Ask
# 2251007                                                  Heartbreaker
# 96267                                                 The Bone Houses
#
#                                                                                              genre_and_votes
# 861044   {'Fantasy': 46400, 'Young Adult': 15083, 'Fiction': 13083, 'Fantasy-Magic': 3815, 'Childrens': 2...
# 2083381                                           {'Fantasy': 46485, 'Young Adult': 15194, 'Fiction': 13064}
# 1584855  {'Fantasy': 59818, 'Fiction': 17918, 'Young Adult': 17892, 'Fantasy-Magic': 4974, 'Childrens': 4...
# 1028676  {'Fantasy': 49784, 'Young Adult': 15393, 'Fiction': 14272, 'Fantasy-Magic': 4199, 'Childrens': 3...
# 2251360                                           {'Fantasy': 48257, 'Young Adult': 15483, 'Fiction': 13649}
# ...                                                                                                      ...
# 1229539                                                   {'Romance': 38, 'Dark': 37, 'Sociology-Abuse': 17}
# 534649                                                                        {'Science Fiction Fantasy': 1}
# 1541052                                                          {'Fiction': 4, 'Mystery': 3, 'Thriller': 2}
# 2251007                                                                   {'Romance': 20, 'Contemporary': 6}
# 96267              {'Fantasy': 841, 'Young Adult': 437, 'Horror': 356, 'Historical-Historical Fiction': 159}
#
# [43312 rows x 3 columns]

# %%
selected_items = items[items["item_id_enc"].isin(top_k_indices)]

with pd.option_context("max_colwidth", 100):
   display(selected_items[["author", "title", "genre_and_votes"]])

# %% [markdown]
# # === Базовые подходы: валидация

# %% [markdown]
# # === Двухстадийный подход: метрики

# %% [markdown]
# # === Двухстадийный подход: модель

# %% [markdown]
# # === Двухстадийный подход: построение признаков
